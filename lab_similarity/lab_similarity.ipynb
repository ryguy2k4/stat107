# %% [markdown]
# # Welcome to Lab: Similarity 🧍🧍‍♂️🧍‍♀️
#
# Many of you already know your tablemates in this class. However, have you ever wondered if there is someone **even more similar** to you than the people you already know?
#
# In this lab, we'll once again explore the dataset from the **Hello Survey** you've completed, utilizing some new Python skills to calculate your similarity to your peers!
#
# A few tips to remember:
#
# - **You are not alone on your journey in learning programming!**  You have your lab Teaching Assistant, your Course Aides, your lab group, and the professors (Prof. Wade and Prof. Karle), who are all here to help you out!
# - If you find yourself stuck for more than a few minutes, ask a neighbor or course staff for help!  When you are giving help to your neighbor, explain the **idea and approach** to the problem without sharing the answer itself so they can have the same **<i>ah-hah</i>** moment!
# - We are here to help you!  Don't feel embarrassed or shy to ask us for help!
#
# Let's get started!

# %%
# Meet your CAs and TA if you haven't already!
# ...first name is enough, we'll know who they are! :)
ta_name = "Alex"
ca1_name = ""
ca2_name = ""


# Say hello to each other!
# - Groups of 3 are ideal :)
# - However, groups of 2 or 4 are fine too!

# QOTD to ask your group: What's your favorite (or least favorite) building on campus? 
partner1_name = "Bryan"
partner1_netid = "bryanfw2"
partner1_favbuilding = "ACES Library"

partner2_name = "Zijian"
partner2_netid = ""
partner2_favbuilding = "CIF"

partner3_name = ""
partner3_netid = ""
partner3_favbuilding = ""

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# # Part 1: Hello, Again

# %% [markdown]
# ## Load the Hello Dataset
# To find those most similar to you in this course, we're going to need the good old Hello Dataset.
#
#
# The "Hello Dataset" is available here:
# ```
# https://waf.cs.illinois.edu/discovery/hello-fa23.csv
# ```
#
# Use Python to load this dataset into a DataFrame `df`:

# %%
import pandas as pd
df = pd.read_csv("https://waf.cs.illinois.edu/discovery/hello-fa23.csv")
df
# Out:
#                 Name   Section  \
# 0        Prof. Karle    L1, L2
# 1         Prof. Wade    L1, L2
# 2             Andrew       Y05
# 3           Annabel        Y05
# 4             Ayden        Y14
# ...              ...       ...
# 1069         CA Soph  Y07, Y16
# 1070          CA Ana       Y14
# 1071  CA Sri Nithya        Y26
# 1072       CA Lauren      YALL
# 1073        CA Subin       Y05
#
#      What is your first name you want us to use for you?  \
# 0                                           Prof. Karle
# 1                                            Prof. Wade
# 2                                                Andrew
# 3                                              Annabel
# 4                                                Ayden
# ...                                                 ...
# 1069                                            CA Soph
# 1070                                             CA Ana
# 1071                                     CA Sri Nithya
# 1072                                          CA Lauren
# 1073                                           CA Subin
#
#      What lab section are you enrolled in?  (Use the three-letter code that starts with a "Y", like "Y42".)  \
# 0                                                L1, L2
# 1                                                L1, L2
# 2                                                   Y05
# 3                                                   Y05
# 4                                                   Y14
# ...                                                 ...
# 1069                                           Y07, Y16
# 1070                                                Y14
# 1071                                                Y26
# 1072                                               YALL
# 1073                                                Y05
#
#      Does your NetID ending with odd number or even number?  \
# 0                         NetID ends with an odd number
# 1                                                   NaN
# 2                         NetID ends with an odd number
# 3                        NetID ends with an even number
# 4                        NetID ends with an even number
# ...                                                 ...
# 1069                     NetID ends with an even number
# 1070                     NetID ends with an even number
# 1071                     NetID ends with an even number
# 1072                     NetID ends with an even number
# 1073                     NetID ends with an even number
#
#      If I flipped a coin, do you think it would it land on heads or tails?  \
# 0                                                 Heads
# 1                                                 Heads
# 2                                                 Heads
# 3                                                 Heads
# 4                                                 Heads
# ...                                                 ...
# 1069                                              Tails
# 1070                                              Heads
# 1071                                              Heads
# 1072                                              Heads
# 1073                                              Tails
#
#      Do you like to eat tacos or donuts?  Pick a Number: 0 or 1  \
# 0                                  Tacos                    0.0
# 1                                  Tacos                    1.0
# 2                                  Tacos                    1.0
# 3                                  Tacos                    0.0
# 4                                 Donuts                    1.0
# ...                                  ...                    ...
# 1069                              Donuts                    0.0
# 1070                              Donuts                    1.0
# 1071                               Tacos                    1.0
# 1072                               Tacos                    1.0
# 1073                               Tacos                    1.0
#
#      Are you a freshman in college? Are you a morning or a night person?  ...  \
# 0                    Not a Freshman                         Night Person  ...
# 1                    Not a Freshman                         Night Person  ...
# 2               Freshman in College                         Night Person  ...
# 3                    Not a Freshman                         Night Person  ...
# 4               Freshman in College                         Night Person  ...
# ...                             ...                                  ...  ...
# 1069                 Not a Freshman                       Morning Person  ...
# 1070                 Not a Freshman                       Morning Person  ...
# 1071                 Not a Freshman                         Night Person  ...
# 1072                 Not a Freshman                       Morning Person  ...
# 1073                 Not a Freshman                         Night Person  ...
#
#      From 1 to 10, how happy are you right now?  \
# 0                                          9.00
# 1                                          8.25
# 2                                          7.00
# 3                                          5.00
# 4                                          8.00
# ...                                         ...
# 1069                                       3.50
# 1070                                       8.00
# 1071                                       6.00
# 1072                                       7.00
# 1073                                       5.00
#
#      The level of spiciness you're comfortable with (None, mild, moderate, strong, extreme)?  \
# 0                                              moderate
# 1                                              Moderate
# 2                                              moderate
# 3                                              Moderate
# 4                                                Strong
# ...                                                 ...
# 1069                                           Moderate
# 1070                                               mild
# 1071                                            extreme
# 1072                                             Strong
# 1073                                           moderate
#
#      What college is your intended major in?  (This is where you hope to end up, not necessarily your current major.)  \
# 0                                            Statistics
# 1                                              Grainger
# 2                                                   LAS
# 3                                      ISchool and LAS
# 4                                                  Gies
# ...                                                 ...
# 1069                                                LAS
# 1070                                          Economics
# 1071                     School of Information Sciences
# 1072                                        Advertising
# 1073                                            iSchool
#
#      What do you think is the hardest major at UIUC?  \
# 0                              Anything in GRAINGER!
# 1                                            Physics
# 2                                                 CS
# 3                                  Computer science
# 4                                    Any engineering
# ...                                              ...
# 1069                                  Bioengineering
# 1070                            Computer engineering
# 1071                            Computer Engineering
# 1072                                Computer Science
# 1073                                             ECE
#
#      What genre of music do you listen to? Who is your favorite music artist?  \
# 0                            TAYLOR SWIFT!                       Taylor Swift
# 1                              Pop and EDM                       Taylor Swift
# 2                                      rap                               Dave
# 3                               Rap or r&b                            Eminem
# 4                                Indie pop                      The Lumineers
# ...                                    ...                                ...
# 1069                                  Punk                         Waterparks
# 1070                                   Rap                         Noah Kahan
# 1071                                   R&B                       Metro Boomin
# 1072                            indie rock                      Dominic fike
# 1073                           Hip Hop/Rap                       Travis Scott
#
#      What's your favorite social media app? How do you respond to I-L-L?  \
# 0                                 Instagram                        I-N-I
# 1                                   YouTube                        I-N-I
# 2                                 instagram                        I-N-I
# 3                                 Snapchat                           INI
# 4                                  Snapchat                          INI
# ...                                     ...                          ...
# 1069                                 TikTok                        I-N-I
# 1070                               Snapchat                        I-L-L
# 1071                              Instagram                        I-N-I
# 1072                              Instagram                          INI
# 1073                                Twitter                        I-N-I
#
#      What is your favorite game to play (either video game or IRL)?  \
# 0                                 Any type of card game
# 1                                              Factorio
# 2                                                soccer
# 3                              Volleyball or fortnight
# 4                                            Basketball
# ...                                                 ...
# 1069                                       Just Dance 4
# 1070                                             Tennis
# 1071                                      hide and seek
# 1072                            Capture the Flag Lowkey
# 1073                                         Basketball
#
#      What is your dream vacation location?
# 0                             The Maldives
# 1                                Mountains
# 2                                   Hawaii
# 3                                  Greece
# 4                               Australia
# ...                                    ...
# 1069                               Croatia
# 1070                                 Italy
# 1071                        banff, canada
# 1072                          Tokyo, Japan
# 1073                           Switzerland
#
# [1074 rows x 180 columns]

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == CHECKPOINT TEST CASES ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any errors, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
assert("df" in vars()), "This is not the Hello dataset you're looking for. Check the URL."
assert("Do you like to eat tacos or donuts?" in df), "This is not the Hello dataset you're looking for. Check the URL."
assert(len(df) >= 1074), "This is not the Hello dataset you're looking for. Check the URL."

## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ## Finding Yourself
# There is no finding people you are **similar to** before finding **yourself** - literally!
#
# ### Puzzle 1.1: Your Row
# In the following cell, write the Python code to create a **new** DataFrame with only yourself, named `df_me`:

# %%
df_me = df[(df.Name == "Ryan") & (df.Section == "Y30")]
df_me
# Out:
#     Name Section What is your first name you want us to use for you?  \
# 12  Ryan     Y30                                               Ryan
#
#    What lab section are you enrolled in?  (Use the three-letter code that starts with a "Y", like "Y42".)  \
# 12                                                Y30
#
#    Does your NetID ending with odd number or even number?  \
# 12                     NetID ends with an even number
#
#    If I flipped a coin, do you think it would it land on heads or tails?  \
# 12                                              Heads
#
#    Do you like to eat tacos or donuts?  Pick a Number: 0 or 1  \
# 12                              Donuts                    0.0
#
#    Are you a freshman in college? Are you a morning or a night person?  ...  \
# 12            Freshman in College                         Night Person  ...
#
#    From 1 to 10, how happy are you right now?  \
# 12                                       10.0
#
#    The level of spiciness you're comfortable with (None, mild, moderate, strong, extreme)?  \
# 12                                           Moderate
#
#    What college is your intended major in?  (This is where you hope to end up, not necessarily your current major.)  \
# 12                                                LAS
#
#    What do you think is the hardest major at UIUC?  \
# 12                                         Physics
#
#    What genre of music do you listen to? Who is your favorite music artist?  \
# 12                                  Rock               Two Door Cinema Club
#
#    What's your favorite social media app? How do you respond to I-L-L?  \
# 12                                youtube                  **silence**
#
#    What is your favorite game to play (either video game or IRL)?  \
# 12                                         Overcooked
#
#    What is your dream vacation location?
# 12             Grand Teton National Park
#
# [1 rows x 180 columns]

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == PUZZLE 1.1 TEST CASES ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any errors, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
assert("df_me" in vars()), "Make sure you named the DataFrame with just you `df_me`."
assert("Do you like to eat tacos or donuts?" in df_me), "Your `df_me` should have the same columns as our `df`."
assert(len(df_me.columns.to_list()) == 180), "Your `df_me` should have the same number of columns as our original `df`."
assert(len(df_me) == 1), "Your `df_me` should only have one row: yourself."

## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ## Dataframe vs. Series
#
# Before we continue, a brief lesson on some of the datatypes you'll encounter in this class.
#
# In `pandas`, there are three data structures we will be using, two of which you have already seen:
#
# - A **DataFrame** is similar to an Excel sheet. It contains zero or more rows and zero or more columns. It can contain up to an unlimited number of rows and columns and is the basic data structure we've worked with from the start
#
# - A **GroupBy** is a grouping of rows within a DataFrame. This "three dimensional data" requires us to use `agg` to reduce it back down to a DataFrame - which you've been doing in homeworks and labs thus far!
#
# - A **Series** is a single row with zero or more values (columns). You can think of a DataFrame as a collection of **Series** objects. When we deal with a single row, we will usually want to deal with a **Series** instead of a **one row DataFrame**
#
# In this lab, we will learn how to convert from a **one row DataFrame** to a **Series**, but here's a quick recap on how to convert from types:

# %% [markdown]
# ### Converting Types
#
# The `pandas` library makes it easy to convert between a **Series**, **DataFrame**, and **GroupBy**.
#
# - From a **Series** (`row`) to a **DataFrame**
#     - `row.to_frame()`
# - From a **DataFrame** (`df`) to a **GroupBy**:
#     - `df.groupby('columnName')` -- (You know this already!)
# - From a **GroupBy** (`group`) to a **DataFrame**:
#     - `group.agg( function )` -- (You know this already!)
# - From a **DataFrame** (`df`) to a **Series**:
#     - `df.iloc[0]`, if the DataFrame has one row
#
# See this guide, https://discovery.cs.illinois.edu/guides/DataFrame-Fundamentals/dataframe-loc-vs-iloc/, for more information about `iloc[]`.

# %% [markdown]
# ### Puzzle 1.2: Transform your row into a Series
# Using the correct function from above, **transform** the `df_me` row containing only you from a **one-row DataFrame** into a **Series**.
#
# Make sure the Series is named `my_row` (this will match up with code we provide you with later):

# %%
my_row = df_me.iloc[0]
my_row
# Out:
# Name                                                                                                                                Ryan
# Section                                                                                                                              Y30
# What is your first name you want us to use for you?                                                                                 Ryan
# What lab section are you enrolled in?  (Use the three-letter code that starts with a "Y", like "Y42".)                               Y30
# Does your NetID ending with odd number or even number?                                                    NetID ends with an even number
#                                                                                                                        ...
# Who is your favorite music artist?                                                                                  Two Door Cinema Club
# What's your favorite social media app?                                                                                           youtube
# How do you respond to I-L-L?                                                                                                 **silence**
# What is your favorite game to play (either video game or IRL)?                                                                Overcooked
# What is your dream vacation location?                                                                          Grand Teton National Park
# Name: 12, Length: 180, dtype: object

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == PUZZLE 1.2 TEST CASES ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any errors, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
assert('my_row' in vars()), "Your series should be named `my_row`."
assert(type(my_row) == pd.core.series.Series), "Make sure you've correctly converted your one-row DataFrame into a Series..."

## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ## Choosing Your Columns

# %% [markdown]
# Before we begin, we have to think about our approach to finding your DISCOVERY twin.
#
# You may have noticed our Hello Dataset has **almost 100 questions**. Instead of finding the most similar person to you using **every question**, we'll pick out a few questions to analyze.
#
# **But first, we need to revisit the questions.**
#
# Recall the function `df.columns.tolist()`. To recap, this command will list **all of the columns** (in this case, our questions) in a DataFrame.
#
#  Use `df.columns.tolist()` in the cell below.
#
# You will likely see the message: Output exceeds the __size limit__. Open the full output data __in a text editor__.
#
# If you do, click the **in a text editor** link to open the whole list in a new tab of VSCode.

# %%
df.columns.tolist()
# Out:
# ['Name',
#  'Section',
#  'What is your first name you want us to use for you?',
#  'What lab section are you enrolled in?  (Use the three-letter code that starts with a "Y", like "Y42".)',
#  'Does your NetID ending with odd number or even number?',
#  'If I flipped a coin, do you think it would it land on heads or tails?',
#  'Do you like to eat tacos or donuts?',
#  'Pick a Number: 0 or 1',
#  'Are you a freshman in college?',
#  'Are you a morning or a night person?',
#  'Are you a morning or an afternoon person?',
#  'Are you a student from Illinois or out-of-state?',
#  'Are you a student in Grainger?',
#  'Are you a Taylor Swift fan?',
#  'Are you a winter or summer person?',
#  'Are you above or equal to 5 foot 6 inches?',
#  'Are you an early bird or night owl?',
#  'Are you an extrovert or an introvert?',
#  'Are you an international student or from the United States?',
#  'Are you an underclassmen or lowerclassmen?',
#  'Is the day of the month of your birth even or odd?  (Ex: May 28 is even, but June 3 is odd)',
#  'Are you from the Chicago suburbs?',
#  'Are you in LAS?',
#  'Are you in the 9:00 AM or 11:00 AM DISCOVERY lecture?',
#  'Are you involved/will be involved in Greek life?',
#  'Are you living on or off campus?',
#  'Do you identify as a male or female?',
#  'Are you older than 18?',
#  'Are you sitting in a light or dark colored chair?',
#  'Are you the first person from your entire family to attend University of Illinois?',
#  'Are you wearing glasses right now?',
#  'Are your parents immigrants?',
#  'Beef or Chicken?',
#  'Chocolate or Vanilla?',
#  'Coffee or Tea?',
#  'Coke or Pepsi? ',
#  'Did you attend lecture on Friday?',
#  'Did you grow up in the Midwest?',
#  'Did you move in from the 13-16th or the 17-20th?',
#  'Did you sit on the left or the right side of the hall during the last lecture?',
#  'Do you consider a cup to be half empty or half full?',
#  'Do you dance?',
#  'Do you drink black coffee?',
#  'Do you drink coffee every day?',
#  'Do you eat breakfast in the morning?',
#  'Do you grow up in Illinois?',
#  'Do you hang your toilet paper over or under?',
#  'Do you have an iPhone?',
#  'Do you have an odd or even amount of letters in your first name?',
#  'Do you have any siblings?',
#  'Do you have black hair or non-black hair?',
#  'Do you have brown eyes or any other color?',
#  'Do you have short hair or long hair?',
#  'Do you have your Data Science Discovery lab section on Wednesday or after Wednesday?',
#  'Do you have your ears pierced?',
#  'Do you introduce yourself to a new person using "hi" or "hello"?',
#  'Do you like C++ or Java?',
#  'Do you like Chinese food?',
#  'Do you like dogs or cats?',
#  'Do you like football or basketball better?',
#  'Do you like ice cream?',
#  'Do you like orange juice or apple juice?',
#  'Do you like pancakes or waffles?',
#  'Pink or Blue?',
#  'Pizza or a burger?',
#  'Pizza or pasta?',
#  'Summer or Winter?',
#  'Do you like to wear hats?',
#  'Do you like UIUC?',
#  'Do you listen to music on the way to classes?',
#  'Do you live in a residence hall or private housing?',
#  'Do you prefer Nike or Adidas for shoes?',
#  'Do you prefer vanilla or chocolate ice cream? ',
#  'Burger or Taco?',
#  'Do you prefer American Football or Cricket?',
#  'Do you prefer apples or bananas?',
#  'Do you prefer blue or orange? ',
#  'Do you prefer blue or pink?',
#  'Do you prefer chipmunks or squirrels?',
#  'Do you prefer Coke or Sprite? ',
#  'Do you prefer cold drinks or hot drinks?',
#  'Do you prefer cold or hot weather?',
#  'Do you prefer crinkle-cut or straight-cut fries?',
#  'Do you prefer earbuds or headphones?',
#  'Do you prefer fall or spring?',
#  'Do you prefer fall or summer?',
#  'Do you prefer green or red?',
#  'Do you prefer Hot Cheetos or Takis?',
#  'Do you prefer Hot Coffee or Ice Coffee?',
#  'Do you prefer hot or iced tea?',
#  'Do you prefer hotdogs or burgers?',
#  'Do you prefer ketchup or ranch?',
#  'Do you prefer Mac or Windows?',
#  'Do you prefer Marvel or DC comics?',
#  'Do you prefer movies or TV shows?',
#  'Do you prefer online class or in-person class?',
#  'Pizza or tacos?',
#  'Do you prefer red or blue?',
#  'Do you prefer regular or diet soda?',
#  'Do you prefer Soccer or American Football?',
#  'Do you prefer spend your time outdoor or indoor?',
#  'Superman or batman?',
#  'Do you prefer sweet or salty foods?',
#  'Do you prefer sweet or savory food?',
#  'Do you prefer sweet or sour foods?',
#  'Do you prefer the color YELLOW or the color ORANGE?',
#  'Do you prefer the letter "M" or "N"?',
#  'Do you prefer the number 3 or the number 4?',
#  'Do you prefer to eat at ISR or IKE?',
#  'Do you prefer to have pets or no pets?',
#  'Do you prefer to listen to audio through headphones or speakers?',
#  'Do you prefer to shower at night or in the morning?',
#  'Do you prefer vegetables or fruit?',
#  'Do you pronounce caramel as "care-a-mel" or "car-mel"?',
#  'Do you pronounce Illinois "Ill-uh-noise" or "Ill-uh-noy"?',
#  'Do you pronounce the word "data" like "dah-tah" or "day-tah?"',
#  'Do you put ketchup on your hotdog?',
#  'Do you speak a language other than English?',
#  'Do you think there are more doors or wheels in the world?',
#  'Do you use Spotify or Apple Music?',
#  'Do you walk to class?',
#  'Do you wear glasses or contacts?',
#  'Does pineapple belong on pizza?',
#  'Does your first name start with a letter between A-M? (including A and M)?',
#  'Does your last name start with any letter between "A" through "L" or "M" through "Z"?',
#  'Does your UIN end with an even number or an odd number? (0 is considered an even number)',
#  'Folklore or Evermore?',
#  'Have you traveled outside of the USA this summer?',
#  'Have you ever traveled outside the USA?',
#  'Is a hotdog a sandwich?',
#  'Is math red or blue?',
#  'Is the last digit of your phone number even?',
#  'Is water wet?',
#  'Is your age an even number or an odd number?',
#  'Is your month of your birth odd or even?',
#  'Is your birthday before/on or after July 1st?',
#  'Is your day good or bad?',
#  'Is your dorm/apartment room number even?',
#  'Is your favorite color blue?',
#  'Is your favorite number even?',
#  'Is your major STEM or a humanity?',
#  'Lebron or Jordan?',
#  'Popeyes or KFC?',
#  'Was UIUC your first choice school when applying for college? ',
#  'Were you born before Feb. 14, 2005?',
#  'What came first, the chicken or the egg?',
#  'Which is the better ice cream flavor: chocolate chip or vanilla?',
#  'Which movie do you prefer Barbie or Oppenheimer?',
#  'Which number do you prefer: 49 or 62?',
#  'Which Ryan is better, Ryan Gosling or Ryan Reynolds?',
#  'which sequence do you prefer more tbge5 or pbt2l?',
#  'Who would win in a fight, Cinderella or Snow White?',
#  'Would you choose Mexican or Italian food?',
#  'Would you prefer to live an urban or rural life?',
#  'Would you rather get a book about your past or a letter revealing something about your future?',
#  'Would you rather go to an amusement park or beach?',
#  'Would you rather have a personal theme song that plays every time you enter a room, or have a spotlight follow you everywhere you go?',
#  'Would you rather have hiccups for the rest of your life or constantly feel like you have to sneeze?',
#  'Would you rather know how you die or when you die?',
#  'Would you rather never use a phone or computer again?',
#  'Would you rather take notes on a computer/tablet or paper?',
#  'In terms of Data Science, do you prefer statistics or computer science?',
#  'How many classes are you taking this semester?',
#  'How many credit hours are you taking?',
#  'How many hours do you sleep in a day?',
#  'How many siblings do you have?',
#  'What is your phone battery percentage currently at?',
#  'How many people is the ideal number of people at a party?',
#  'What is the lowest numbered course you are taking this semester?',
#  'What is your shoe size (US size)?',
#  'From 1 to 10, how happy are you right now?',
#  "The level of spiciness you're comfortable with (None, mild, moderate, strong, extreme)?",
#  'What college is your intended major in?  (This is where you hope to end up, not necessarily your current major.)',
#  'What do you think is the hardest major at UIUC?',
#  'What genre of music do you listen to?',
#  'Who is your favorite music artist?',
#  "What's your favorite social media app?",
#  'How do you respond to I-L-L?',
#  'What is your favorite game to play (either video game or IRL)?',
#  'What is your dream vacation location?']

# %% [markdown]
# ### Puzzle 1.3: Choosing Your Columns
# From the above list of **columns** (questions), choose **at least 12 questions** to work with moving forward. Please use **only questions with binary answers** for this part of the analysis :)
#
# These will be the questions used to **calculate your similarity** to other people in DISCOVERY! Feel free to include more if you'd like.
#
# Store them as a **list** of **strings** named `questions` in the Python cell below:

# %%
questions = [
  'Are you a morning or a night person?',
  'Are you a winter or summer person?',
  'Are you an extrovert or an introvert?',
  'Are you from the Chicago suburbs?',
  'Do you like dogs or cats?',
  'Do you prefer Mac or Windows?',
  'Does pineapple belong on pizza?',
  'Is your major STEM or a humanity?',
  'Are you wearing glasses right now?',
  'Do you have brown eyes or any other color?',
  'Do you prefer sweet or salty foods?',
  'Do you pronounce the word "data" like "dah-tah" or "day-tah?"'
]

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == PUZZLE 1.3 TEST CASES ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any errors, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
assert('questions' in vars()), "Please name your list of questions `questions`."
assert(type(questions) == list and type(questions[0]) == str), "Make sure your `questions` variable is a list of strings."
assert(len(questions) >= 12), "Do you have at least 12 questions in your columns list?"
for q in questions:
   assert(q in df), "Double check that you've copied each question correctly. The question texts should match up EXACTLY with the output from `df.columns.to_list()`."
for q in questions:
   assert(len(df[q].value_counts()) == 2), "Make sure that you've only included questions with binary answers in your columns list."

## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ### Analysis: Question Choice
#
# **Q1: Explain why you chose the questions you did to evaluate similarity. Is there a question or questions you think that say more about someone than others?**

# %% [markdown]
# I chose questions that I believe I have clear and definitive answers for, and therefore best describe me. the Introvert/Extrovert question definitely holds a lot of weight compared to others.

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# # Part 2: The Similarity Function

# %% [markdown]
# Now that we have chosen the **questions** we'd like to evaluate, it's time to create a **function** to calculate a similarity value for each person, or each row in `df`.
#
# In lecture, remember learning that a Python **function** takes an **input** in and **returns** a **value**.
#
# For this specific function, we will take a **row** and calculate a **similarity score** for that row.
#
# But first, **print your list of questions** using the Python cell below for reference:

# %%
questions
# Out:
# ['Are you a morning or a night person?',
#  'Are you a winter or summer person?',
#  'Are you an extrovert or an introvert?',
#  'Are you from the Chicago suburbs?',
#  'Do you like dogs or cats?',
#  'Do you prefer Mac or Windows?',
#  'Does pineapple belong on pizza?',
#  'Is your major STEM or a humanity?',
#  'Are you wearing glasses right now?',
#  'Do you have brown eyes or any other color?',
#  'Do you prefer sweet or salty foods?',
#  'Do you pronounce the word "data" like "dah-tah" or "day-tah?"']

# %% [markdown]
# ### Puzzle 2.1: The Similarity Function
# We have provided the basic outline for the `similarity` function below. Follow the **commented details** and **complete the function** using all of your questions below:

# %%
def similarity(row):
    # This function will keep track of a `score` of how similar two rows are with each other.
    # The score begins at zero and we will add to it every time a row matches.
    score = 0 

    # This if statement below checks to see if the `row` shares your choice between Coffee and Tea
    # - If the values are the same (==), we add one to the score.
    for q in questions:
        if row[q] == my_row[q]:
             score = score + 1

    # Repeat this syntax many times for EACH question (column) that you have chosen in your list
    # IMPORTANT: Make sure to keep your lines all at this same level of tabbing out from the start.    
    # ALSO: Delete or the replace the "Coffee or Tea?" question,
    #       (unless you've decided that is one of your evaluating questions). 

    # Finally, return the `score`.
    # ...this line (the return statement) should always be the LAST line. 
    return score

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == PUZZLE 2.1 TEST CASES ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any errors, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
assert(similarity(my_row) == len(questions) or similarity(my_row) == my_row[questions].count()), "Ensure you've added all the questions from your list and ONLY questions from your list correctly to your similarity function."

## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ### Puzzle 2.2: Applying the Similarity Function
# Now that you've properly defined the similarity function, we need to **apply** it to the rest of the Hello Dataset DataFrame so we can produce a **similarity score** for each person who took the survey!
#
# Luckily, `pandas` provides a useful function for our use case: `df.apply()`.
#
# Quick lesson: `df.apply(some_function)` applies a pre-defined function named `some_function` along an axis of your DataFrame.
#
# Because we want to run our `similarity` function on all **rows**, when you call `df.apply()`, ensure you use **`axis=1`**. This would look something like:
# ```
# df["score"] = df.apply(some_function, axis=1)
# ```
#
# Using the above explanation as reference, **add a column** named `Similarity Score` to your original DataFrame that contains the value after running your similarity function you defined earlier across all rows:

# %%
df["Similarity Score"] = df.apply(similarity, axis=1)

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == PUZZLE 2.2 TEST CASES ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any errors, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
assert('Similarity Score' in df), "Make sure you've named and added the Similarity Score column to your original df."
assert(df['Similarity Score'].dtype == 'int64'), "Double check that you've called the similarity function correctly in your df.apply()."

## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# # Part 3: Finding your Twin(s)

# %% [markdown]
# Your last column `Similarity Score` in `df` is now a metric (a measurement) of how **similar** you are to everyone else in the class, based on the **questions you've chosen**!
#
# Finally, we can do analytical Data Science!

# %% [markdown]
# ### Puzzle 3.1: Your Twin in 107
#
# Using the Python cell below, find the **person most similar to you in the entire course** (having the largest `Similarity Score`).
#
# Note that **you should be most similar to yourself** (you will always match yourself)! This is not the right answer. Find the person with the highest score ***aside from yourself***.

# %%
df.nlargest(2, "Similarity Score")
# Out:
#     Name Section What is your first name you want us to use for you?  \
# 12  Ryan     Y30                                               Ryan
# 26   Dev     Y12                                                Dev
#
#    What lab section are you enrolled in?  (Use the three-letter code that starts with a "Y", like "Y42".)  \
# 12                                                Y30
# 26                                                Y12
#
#    Does your NetID ending with odd number or even number?  \
# 12                     NetID ends with an even number
# 26                      NetID ends with an odd number
#
#    If I flipped a coin, do you think it would it land on heads or tails?  \
# 12                                              Heads
# 26                                              Heads
#
#    Do you like to eat tacos or donuts?  Pick a Number: 0 or 1  \
# 12                              Donuts                    0.0
# 26                               Tacos                    0.0
#
#    Are you a freshman in college? Are you a morning or a night person?  ...  \
# 12            Freshman in College                         Night Person  ...
# 26            Freshman in College                         Night Person  ...
#
#    The level of spiciness you're comfortable with (None, mild, moderate, strong, extreme)?  \
# 12                                           Moderate
# 26                                           Moderate
#
#    What college is your intended major in?  (This is where you hope to end up, not necessarily your current major.)  \
# 12                                                LAS
# 26                                                LAS
#
#    What do you think is the hardest major at UIUC?  \
# 12                                         Physics
# 26                          Electrical Engineering
#
#    What genre of music do you listen to? Who is your favorite music artist?  \
# 12                                  Rock               Two Door Cinema Club
# 26                               Hip-Hop                      Westside Gunn
#
#    What's your favorite social media app? How do you respond to I-L-L?  \
# 12                                youtube                  **silence**
# 26                                      X                      Shut up
#
#    What is your favorite game to play (either video game or IRL)?  \
# 12                                         Overcooked
# 26                          American Football/Cricket
#
#    What is your dream vacation location? Similarity Score
# 12             Grand Teton National Park               12
# 26                            Staycation               12
#
# [2 rows x 181 columns]

# %% [markdown]
# ### Analysis: True Twin?
#
# **Q2: If you picked twelve or more other questions to evaluate similarity, do you think you'd find a different twin in the course overall?**

# %% [markdown]
# Yes, I think if I chose different questions I might have a different twin, however these are the questions that I feel best represent me, therefore this is probably the closest true twin.

# %% [markdown]
# ### Puzzle 3.2: Your Lab Twin
#
# Now, chances are your twin isn't in your lab section. Because we conveniently have our row, `Similarity Score` applied to the **entire** set of responses to the survey, we can create smaller DataFrames to answer more questions.
#
# We want to find the person most similar to you in **your lab section**, otherwise known as your lab twin! We can create a new DataFrame to answer this question.
#
# However, some of your CAs and TAs, who are part of your lab section, are in more than one lab section! Those who have multiple sections have `Y##, Y##...` in their Sections column. How can we create a DataFrame that includes the CAs and TAs who are in more than one lab section? Python saves the day again.
#
# #### **The `contains` Function**
# In Python, the `contains` function can be used to check if a specific **substring** is present in a **string**.
#
# This will come in handy for us, because we can see if `Y##` is in the **names** of any rows in our DataFrame.
#
# Using the `contains` function, create a **new DataFrame** with everyone in your lab section: `df_section`.
#
# Part of the statement has been completed for you to show you how to use `contains`. Complete it.
#
# *Note that we have to cast our `Name` column of `df` to a **string** by using `.str`.

# %%
df_section = df[(df['Section'].str.contains('Y30'))]
df_section.nlargest(2, "Similarity Score")
# Out:
#      Name Section What is your first name you want us to use for you?  \
# 12   Ryan     Y30                                               Ryan
# 116  Aruv     Y30                                               Aruv
#
#     What lab section are you enrolled in?  (Use the three-letter code that starts with a "Y", like "Y42".)  \
# 12                                                 Y30
# 116                                                Y30
#
#     Does your NetID ending with odd number or even number?  \
# 12                      NetID ends with an even number
# 116                     NetID ends with an even number
#
#     If I flipped a coin, do you think it would it land on heads or tails?  \
# 12                                               Heads
# 116                                              Heads
#
#     Do you like to eat tacos or donuts?  Pick a Number: 0 or 1  \
# 12                               Donuts                    0.0
# 116                               Tacos                    0.0
#
#     Are you a freshman in college? Are you a morning or a night person?  ...  \
# 12             Freshman in College                         Night Person  ...
# 116            Freshman in College                         Night Person  ...
#
#     The level of spiciness you're comfortable with (None, mild, moderate, strong, extreme)?  \
# 12                                            Moderate
# 116                                             Strong
#
#     What college is your intended major in?  (This is where you hope to end up, not necessarily your current major.)  \
# 12                                                 LAS
# 116                                           Grainger
#
#     What do you think is the hardest major at UIUC?  \
# 12                                          Physics
# 116                          Electrical engineering
#
#     What genre of music do you listen to? Who is your favorite music artist?  \
# 12                                   Rock               Two Door Cinema Club
# 116                                   Rap                        Frank Ocean
#
#     What's your favorite social media app? How do you respond to I-L-L?  \
# 12                                 youtube                  **silence**
# 116                              Instagram                       I-N-I!
#
#     What is your favorite game to play (either video game or IRL)?  \
# 12                                          Overcooked
# 116                     Tom Clancy's Rainbow Six Siege
#
#     What is your dream vacation location? Similarity Score
# 12              Grand Teton National Park               12
# 116                           Switzerland                9
#
# [2 rows x 181 columns]

# %% [markdown]
# #### **➡️ Right now, once you have that person, find them in lab!**<br>➡️ *(If they're not here, look for the next similar person.)*
#
# Help them finish their lab and let them find their DISCOVERY twin!  *(Are you twins of each other?)*
#
# Note that there may be ties in `Similarity Score` due to the usage of only parts of the dataset. If you're curious, you can go back and **add more questions** to your `questions` list and `similarity(row)` function, rerunning the code to have more evaluative similarity scores.

# %% [markdown]
# ### Puzzle 3.3: The Course Staff
# A lot of wonderful course staff work together to bring you all the content for Data Science Discovery.
#
# The course staff of 107 consists of the **Professors, TAs, and CAs**. As you saw in the previous parts, they've all completed the Hello Survey too!
#
# Their response under the `name` column is standardized and follows these formats:
# - `Prof. [Name]`,
# - `TA [Name]`, or
# - `CA [Name]`
#
# The `contains` function will come in handy for us once again, because we can see if `"CA "`, `"TA "`, or `"Prof. "` is in the **names** of any rows in our DataFrame.
#
# Using the `contains` function, create a **new DataFrame** with just the course staff: `df_staff`.
#
# Part of the statement has been completed for you to show you how to use `contains`. Complete it.
#
# *Note that we have to cast our `Name` column of `df` to a **string** by using `.str`.

# %%
df_staff = df[(df['Name'].str.contains('CA ')) | (df['Name'].str.contains('TA ')) | (df['Name'].str.contains('Prof. '))] 
df_staff
# IMPORTANT: Make sure you include a whitespace in "CA "" and "TA "" so that people with those
# #          letters in their name aren't included.  Whitespace matters! :)
# Out:
#                 Name        Section  \
# 0        Prof. Karle         L1, L2
# 1         Prof. Wade         L1, L2
# 199        CA Alyssa  Y21, Y35, Y18
# 350         CA Amaan            Y04
# 463           CA Ram            Y31
# ...              ...            ...
# 1069         CA Soph       Y07, Y16
# 1070          CA Ana            Y14
# 1071  CA Sri Nithya             Y26
# 1072       CA Lauren           YALL
# 1073        CA Subin            Y05
#
#      What is your first name you want us to use for you?  \
# 0                                           Prof. Karle
# 1                                            Prof. Wade
# 199                                           CA Alyssa
# 350                                            CA Amaan
# 463                                              CA Ram
# ...                                                 ...
# 1069                                            CA Soph
# 1070                                             CA Ana
# 1071                                     CA Sri Nithya
# 1072                                          CA Lauren
# 1073                                           CA Subin
#
#      What lab section are you enrolled in?  (Use the three-letter code that starts with a "Y", like "Y42".)  \
# 0                                                L1, L2
# 1                                                L1, L2
# 199                                       Y21, Y35, Y18
# 350                                                 Y04
# 463                                                 Y31
# ...                                                 ...
# 1069                                           Y07, Y16
# 1070                                                Y14
# 1071                                                Y26
# 1072                                               YALL
# 1073                                                Y05
#
#      Does your NetID ending with odd number or even number?  \
# 0                         NetID ends with an odd number
# 1                                                   NaN
# 199                       NetID ends with an odd number
# 350                      NetID ends with an even number
# 463                      NetID ends with an even number
# ...                                                 ...
# 1069                     NetID ends with an even number
# 1070                     NetID ends with an even number
# 1071                     NetID ends with an even number
# 1072                     NetID ends with an even number
# 1073                     NetID ends with an even number
#
#      If I flipped a coin, do you think it would it land on heads or tails?  \
# 0                                                 Heads
# 1                                                 Heads
# 199                                               Tails
# 350                                               Heads
# 463                                               Heads
# ...                                                 ...
# 1069                                              Tails
# 1070                                              Heads
# 1071                                              Heads
# 1072                                              Heads
# 1073                                              Tails
#
#      Do you like to eat tacos or donuts?  Pick a Number: 0 or 1  \
# 0                                  Tacos                    0.0
# 1                                  Tacos                    1.0
# 199                               Donuts                    0.0
# 350                                Tacos                    1.0
# 463                                Tacos                    0.0
# ...                                  ...                    ...
# 1069                              Donuts                    0.0
# 1070                              Donuts                    1.0
# 1071                               Tacos                    1.0
# 1072                               Tacos                    1.0
# 1073                               Tacos                    1.0
#
#      Are you a freshman in college? Are you a morning or a night person?  ...  \
# 0                    Not a Freshman                         Night Person  ...
# 1                    Not a Freshman                         Night Person  ...
# 199                  Not a Freshman                       Morning Person  ...
# 350                  Not a Freshman                       Morning Person  ...
# 463                  Not a Freshman                         Night Person  ...
# ...                             ...                                  ...  ...
# 1069                 Not a Freshman                       Morning Person  ...
# 1070                 Not a Freshman                       Morning Person  ...
# 1071                 Not a Freshman                         Night Person  ...
# 1072                 Not a Freshman                       Morning Person  ...
# 1073                 Not a Freshman                         Night Person  ...
#
#      The level of spiciness you're comfortable with (None, mild, moderate, strong, extreme)?  \
# 0                                              moderate
# 1                                              Moderate
# 199                                           Moderate
# 350                                            Extreme
# 463                                              Strong
# ...                                                 ...
# 1069                                           Moderate
# 1070                                               mild
# 1071                                            extreme
# 1072                                             Strong
# 1073                                           moderate
#
#      What college is your intended major in?  (This is where you hope to end up, not necessarily your current major.)  \
# 0                                            Statistics
# 1                                              Grainger
# 199                                                 LAS
# 350                                           Grainger
# 463                                                Math
# ...                                                 ...
# 1069                                                LAS
# 1070                                          Economics
# 1071                     School of Information Sciences
# 1072                                        Advertising
# 1073                                            iSchool
#
#      What do you think is the hardest major at UIUC?  \
# 0                              Anything in GRAINGER!
# 1                                            Physics
# 199                                              ECE
# 350                            Computer Engineering
# 463                             Computer Engineering
# ...                                              ...
# 1069                                  Bioengineering
# 1070                            Computer engineering
# 1071                            Computer Engineering
# 1072                                Computer Science
# 1073                                             ECE
#
#      What genre of music do you listen to? Who is your favorite music artist?  \
# 0                            TAYLOR SWIFT!                       Taylor Swift
# 1                              Pop and EDM                       Taylor Swift
# 199                                 indie                          boygenius
# 350                               Hip Hop                              Drake
# 463                                   Kpop                           NewJeans
# ...                                    ...                                ...
# 1069                                  Punk                         Waterparks
# 1070                                   Rap                         Noah Kahan
# 1071                                   R&B                       Metro Boomin
# 1072                            indie rock                      Dominic fike
# 1073                           Hip Hop/Rap                       Travis Scott
#
#      What's your favorite social media app? How do you respond to I-L-L?  \
# 0                                 Instagram                        I-N-I
# 1                                   YouTube                        I-N-I
# 199                                 Twitter                        I-N-I
# 350                              Instagram                         I-N-I
# 463                                 Discord                          ...
# ...                                     ...                          ...
# 1069                                 TikTok                        I-N-I
# 1070                               Snapchat                        I-L-L
# 1071                              Instagram                        I-N-I
# 1072                              Instagram                          INI
# 1073                                Twitter                        I-N-I
#
#      What is your favorite game to play (either video game or IRL)?  \
# 0                                 Any type of card game
# 1                                              Factorio
# 199                                      Stardew Valley
# 350                                           Football
# 463                                           Football
# ...                                                 ...
# 1069                                       Just Dance 4
# 1070                                             Tennis
# 1071                                      hide and seek
# 1072                            Capture the Flag Lowkey
# 1073                                         Basketball
#
#      What is your dream vacation location? Similarity Score
# 0                             The Maldives                6
# 1                                Mountains                8
# 199                                 Sydney                7
# 350                                 Italy                 6
# 463                       Sleeping all day                6
# ...                                    ...              ...
# 1069                               Croatia                8
# 1070                                 Italy                6
# 1071                        banff, canada                 6
# 1072                          Tokyo, Japan                5
# 1073                           Switzerland                6
#
# [64 rows x 181 columns]

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == PUZZLE 3.3 TEST CASES ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any errors, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
assert('df_staff' in vars()), "Your DataFrame of course staff should be named 'df_staff'."
assert(len(df_staff) == 64), "Check you've added all the course staff correctly."
assert(len(df_staff.columns.to_list()) == 181), "You should have all of the questions columns and the Similarity Score column in df_staff." 

## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ### Puzzle 3.4: Course Staff Twin!
#
# Now that we have the course staff responses in `df_staff`, find your course staff twin (the staff member who has the **highest Similarity Score** to you).

# %%
df_staff.nlargest(1, "Similarity Score")
# Out:
#            Name Section What is your first name you want us to use for you?  \
# 961  CA Sangjun     Y23                                         CA Sangjun
#
#     What lab section are you enrolled in?  (Use the three-letter code that starts with a "Y", like "Y42".)  \
# 961                                                Y23
#
#     Does your NetID ending with odd number or even number?  \
# 961                     NetID ends with an even number
#
#     If I flipped a coin, do you think it would it land on heads or tails?  \
# 961                                              Heads
#
#     Do you like to eat tacos or donuts?  Pick a Number: 0 or 1  \
# 961                               Tacos                    1.0
#
#     Are you a freshman in college? Are you a morning or a night person?  ...  \
# 961                 Not a Freshman                         Night Person  ...
#
#     The level of spiciness you're comfortable with (None, mild, moderate, strong, extreme)?  \
# 961                                               Mild
#
#     What college is your intended major in?  (This is where you hope to end up, not necessarily your current major.)  \
# 961                                         Statistics
#
#     What do you think is the hardest major at UIUC?  \
# 961                                     Engineering
#
#     What genre of music do you listen to? Who is your favorite music artist?  \
# 961                                   RnB                      Wave to Earth
#
#     What's your favorite social media app? How do you respond to I-L-L?  \
# 961                              Instagram                          INI
#
#     What is your favorite game to play (either video game or IRL)?  \
# 961                                     Clash of Clans
#
#     What is your dream vacation location? Similarity Score
# 961                                 Korea               11
#
# [1 rows x 181 columns]

# %% [markdown]
# ### Analysis: Final Reflection
#
# **Q3: Do you think our method of finding similar people is effective? Why or why not? What could improve it?**

# %% [markdown]
# Yes, I believe this method is effective because it considers a lot of different factors (12 different questions), so that makes it pretty accurate. Given that this is the only data we have to determine similar people, I don't think it can be improved without better data.

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# # Submission
#
# You're almost done!  All you need to do is to commit your lab to GitHub:
#
# 1.  ⚠️ **Make certain to save your work.** ⚠️ To do this, go to **File => Save All**
#
# 2.  After you have saved, exit this notebook and follow the Canvas instructions to commit this lab to your Git repository!
#
# 3. Your TA will grade your submission and provide you feedback after the lab is due. :)
