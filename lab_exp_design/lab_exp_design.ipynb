# %% [markdown]
# # Welcome to Lab: Experimental Design 👨‍🔬⚗️🧪
#
# Before this lab section, you completed the "Hello Survey" based on the questions you generated with your groups.  This week, you will do an analysis of the results and explore techniques to do great experimental design in Python!
#
# A few tips to remember:
#
# - **You are not alone on your journey in learning programming!**  You have your lab Teaching Assistant, your Course Aides, your lab group, and the professors (Prof. Wade and Prof. Karle), who are all here to help you out!
# - If you find yourself stuck for more than a few minutes, ask a neighbor or course staff for help!  When you are giving help to your neighbor, explain the **idea and approach** to the problem without sharing the answer itself so they can have the same **<i>ah-hah</i>** moment!
# - We are here to help you!  Don't feel embarrassed or shy to ask us for help!
#
# Let's get started!

# %% [markdown]
# <hr style="color: #DD3403;">

# %%
# Meet your CAs and TA if you haven't already!
# ...first name is enough, we'll know who they are! :)
ta_name = "Alex"
ca1_name = "Page"
ca2_name = "Evan"
ca3_name = "Areeba"


# Say hello to each other!
# - Groups of 3 are ideal :)
# - However groups of 2 or 4 are fine too!
partner1_name = "Zijian Shen"
partner1_netid = "zijians3"
partner1_inYourGroupLastWeek = "no"

partner2_name = ""
partner2_netid = ""
partner1_inYourGroupLastWeek = "yes"

partner3_name = ""
partner3_netid = ""
partner1_inYourGroupLastWeek = "yes"

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# # Part 1: Hello Dataset Analysis
#
# In lab last week, you created a series of questions that made up the **"Hello Dataset"**.  Before lab, you completed this survey along with the entire course.  Today, you're going to do analysis on this dataset! :)

# %% [markdown]
# ## Your Binary Question Analysis
#
# You will be analyzing the **binary question** your group asked the class from `lab_pandas` -- record it below.  If multiple people from your group had different binary questions, decide which one to use and record that question below.

# %% [markdown]
# Do you shower in the morning or evening?

# %% [markdown]
# ## Load the Hello Dataset
#
# The "Hello Dataset" is available here:
# ```
# https://waf.cs.illinois.edu/discovery/hello-fa23.csv
# ```
#
# Use Python to load this dataset into a DataFrame called `df`. Don't forget to import pandas as well!

# %%
import pandas as pd

df = pd.read_csv("https://waf.cs.illinois.edu/discovery/hello-fa23.csv")

# %% [markdown]
# ## Find The Variable for Your Question
#
# The command `df.columns.tolist()` will **list all of the columns (variables)** in a DataFrame.  Use `df.columns.tolist()` and read the output until you find the column name for your binary question.
#
# - You may see the message: `Output exceeds the __size limit__. Open the full output data __in a text editor__`
# - If you do, click the **`__in a text editor__`** link to open the whole list in a new tab. :)

# %%
df.columns.tolist()
# Out:
# ['Name',
#  'Section',
#  'Does your NetID ending with odd number or even number?',
#  'If I flipped a coin, do you think it would it land on heads or tails?',
#  'Do you like to eat tacos or donuts?',
#  'Pick a Number: 0 or 1',
#  'Are you a freshman in college?',
#  'Are you a morning or a night person?',
#  'Are you a morning or an afternoon person?',
#  'Are you a student from Illinois or out-of-state?',
#  'Are you a student in Grainger?',
#  'Are you a Taylor Swift fan?',
#  'Are you a winter or summer person?',
#  'Are you above or equal to 5 foot 6 inches?',
#  'Are you an early bird or night owl?',
#  'Are you an extrovert or an introvert?',
#  'Are you an international student or from the United States?',
#  'Are you an underclassmen or lowerclassmen?',
#  'Is the day of the month of your birth even or odd?  (Ex: May 28 is even, but June 3 is odd)',
#  'Are you from the Chicago suburbs?',
#  'Are you in LAS?',
#  'Are you in the 9:00 AM or 11:00 AM DISCOVERY lecture?',
#  'Are you involved/will be involved in Greek life?',
#  'Are you living on or off campus?',
#  'Do you identify as a male or female?',
#  'Are you older than 18?',
#  'Are you sitting in a light or dark colored chair?',
#  'Are you the first person from your entire family to attend University of Illinois?',
#  'Are you wearing glasses right now?',
#  'Are your parents immigrants?',
#  'Beef or Chicken?',
#  'Chocolate or Vanilla?',
#  'Coffee or Tea?',
#  'Coke or Pepsi? ',
#  'Did you attend lecture on Friday?',
#  'Did you grow up in the Midwest?',
#  'Did you move in from the 13-16th or the 17-20th?',
#  'Did you sit on the left or the right side of the hall during the last lecture?',
#  'Do you consider a cup to be half empty or half full?',
#  'Do you dance?',
#  'Do you drink black coffee?',
#  'Do you drink coffee every day?',
#  'Do you eat breakfast in the morning?',
#  'Do you grow up in Illinois?',
#  'Do you hang your toilet paper over or under?',
#  'Do you have an iPhone?',
#  'Do you have an odd or even amount of letters in your first name?',
#  'Do you have any siblings?',
#  'Do you have black hair or non-black hair?',
#  'Do you have brown eyes or any other color?',
#  'Do you have short hair or long hair?',
#  'Do you have your Data Science Discovery lab section on Wednesday or after Wednesday?',
#  'Do you have your ears pierced?',
#  'Do you introduce yourself to a new person using "hi" or "hello"?',
#  'Do you like C++ or Java?',
#  'Do you like Chinese food?',
#  'Do you like dogs or cats?',
#  'Do you like football or basketball better?',
#  'Do you like ice cream?',
#  'Do you like orange juice or apple juice?',
#  'Do you like pancakes or waffles?',
#  'Pink or Blue?',
#  'Pizza or a burger?',
#  'Pizza or pasta?',
#  'Summer or Winter?',
#  'Do you like to wear hats?',
#  'Do you like UIUC?',
#  'Do you listen to music on the way to classes?',
#  'Do you live in a residence hall or private housing?',
#  'Do you prefer Nike or Adidas for shoes?',
#  'Do you prefer vanilla or chocolate ice cream? ',
#  'Burger or Taco?',
#  'Do you prefer American Football or Cricket?',
#  'Do you prefer apples or bananas?',
#  'Do you prefer blue or orange? ',
#  'Do you prefer blue or pink?',
#  'Do you prefer chipmunks or squirrels?',
#  'Do you prefer Coke or Sprite? ',
#  'Do you prefer cold drinks or hot drinks?',
#  'Do you prefer cold or hot weather?',
#  'Do you prefer crinkle-cut or straight-cut fries?',
#  'Do you prefer earbuds or headphones?',
#  'Do you prefer fall or spring?',
#  'Do you prefer fall or summer?',
#  'Do you prefer green or red?',
#  'Do you prefer Hot Cheetos or Takis?',
#  'Do you prefer Hot Coffee or Ice Coffee?',
#  'Do you prefer hot or iced tea?',
#  'Do you prefer hotdogs or burgers?',
#  'Do you prefer ketchup or ranch?',
#  'Do you prefer Mac or Windows?',
#  'Do you prefer Marvel or DC comics?',
#  'Do you prefer movies or TV shows?',
#  'Do you prefer online class or in-person class?',
#  'Pizza or tacos?',
#  'Do you prefer red or blue?',
#  'Do you prefer regular or diet soda?',
#  'Do you prefer Soccer or American Football?',
#  'Do you prefer spend your time outdoor or indoor?',
#  'Superman or batman?',
#  'Do you prefer sweet or salty foods?',
#  'Do you prefer sweet or savory food?',
#  'Do you prefer sweet or sour foods?',
#  'Do you prefer the color YELLOW or the color ORANGE?',
#  'Do you prefer the letter "M" or "N"?',
#  'Do you prefer the number 3 or the number 4?',
#  'Do you prefer to eat at ISR or IKE?',
#  'Do you prefer to have pets or no pets?',
#  'Do you prefer to listen to audio through headphones or speakers?',
#  'Do you prefer to shower at night or in the morning?',
#  'Do you prefer vegetables or fruit?',
#  'Do you pronounce caramel as "care-a-mel" or "car-mel"?',
#  'Do you pronounce Illinois "Ill-uh-noise" or "Ill-uh-noy"?',
#  'Do you pronounce the word "data" like "dah-tah" or "day-tah?"',
#  'Do you put ketchup on your hotdog?',
#  'Do you speak a language other than English?',
#  'Do you think there are more doors or wheels in the world?',
#  'Do you use Spotify or Apple Music?',
#  'Do you walk to class?',
#  'Do you wear glasses or contacts?',
#  'Does pineapple belong on pizza?',
#  'Does your first name start with a letter between A-M? (including A and M)?',
#  'Does your last name start with any letter between "A" through "L" or "M" through "Z"?',
#  'Does your UIN end with an even number or an odd number? (0 is considered an even number)',
#  'Folklore or Evermore?',
#  'Have you traveled outside of the USA this summer?',
#  'Have you ever traveled outside the USA?',
#  'Is a hotdog a sandwich?',
#  'Is math red or blue?',
#  'Is the last digit of your phone number even?',
#  'Is water wet?',
#  'Is your age an even number or an odd number?',
#  'Is your month of your birth odd or even?',
#  'Is your birthday before/on or after July 1st?',
#  'Is your day good or bad?',
#  'Is your dorm/apartment room number even?',
#  'Is your favorite color blue?',
#  'Is your favorite number even?',
#  'Is your major STEM or a humanity?',
#  'Lebron or Jordan?',
#  'Popeyes or KFC?',
#  'Was UIUC your first choice school when applying for college? ',
#  'Were you born before Feb. 14, 2005?',
#  'What came first, the chicken or the egg?',
#  'Which is the better ice cream flavor: chocolate chip or vanilla?',
#  'Which movie do you prefer Barbie or Oppenheimer?',
#  'Which number do you prefer: 49 or 62?',
#  'Which Ryan is better, Ryan Gosling or Ryan Reynolds?',
#  'which sequence do you prefer more tbge5 or pbt2l?',
#  'Who would win in a fight, Cinderella or Snow White?',
#  'Would you choose Mexican or Italian food?',
#  'Would you prefer to live an urban or rural life?',
#  'Would you rather get a book about your past or a letter revealing something about your future?',
#  'Would you rather go to an amusement park or beach?',
#  'Would you rather have a personal theme song that plays every time you enter a room, or have a spotlight follow you everywhere you go?',
#  'Would you rather have hiccups for the rest of your life or constantly feel like you have to sneeze?',
#  'Would you rather know how you die or when you die?',
#  'Would you rather never use a phone or computer again?',
#  'Would you rather take notes on a computer/tablet or paper?',
#  'In terms of Data Science, do you prefer statistics or computer science?',
#  'How many classes are you taking this semester?',
#  'How many credit hours are you taking?',
#  'How many hours do you sleep in a day?',
#  'How many siblings do you have?',
#  'What is your phone battery percentage currently at?',
#  'How many people is the ideal number of people at a party?',
#  'What is the lowest numbered course you are taking this semester?',
#  'What is your shoe size (US size)?',
#  'From 1 to 10, how happy are you right now?',
#  'What is your first name you want us to use for you?',
#  'What lab section are you enrolled in? (Use the three-letter code that starts with a "Y", like "Y42".)',
#  "The level of spiciness you're comfortable with (None, mild, moderate, strong, extreme)?",
#  'What college is your intended major in?  (This is where you hope to end up, not necessarily your current major.)',
#  'What do you think is the hardest major at UIUC?',
#  'What genre of music do you listen to?',
#  'Who is your favorite music artist?',
#  "What's your favorite social media app?",
#  'How do you respond to I-L-L?',
#  'What is your favorite game to play (either video game or IRL)?',
#  'What is your dream vacation location?']

# %% [markdown]
# ## Record the Variable for Your Question
#
# In the cell below, record your question's column name as a **string** variable named `analysis_column`.  You'll need that exact column name to reference data from that cell.

# %%
analysis_column = "Do you prefer to shower at night or in the morning?"
analysis_column
# Out:
# 'Do you prefer to shower at night or in the morning?'

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == CHECKPOINT TEST CASES ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any error in your output, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
assert('df' in vars()), "You do not have a DataFrame called `df`."
assert(len(df) >= 965), "You have not loaded the correct Hello dataset"
assert(analysis_column in df), "Make certain your analysis_column string is EXACTLY as it appears in the Hello Dataset."

## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ## Column Subset: View Only Your Question's Responses
#
# To begin your question's analysis, you first want to **focus only on your question**.  In lecture, we have primarily focused on creating subsets of rows. However, you can also create a subset of columns!
#
# To create a DataFrame with just a single column, you can use the syntax:
# ```
# df[ ["column name"] ]
# ```
# - Notice the **double set of square brackets**.  You need the outer set for `df`, and the inner set for the column name.
# - Because we've already loaded your question into `analysis_column`, you won't need the quotation marks this time
# - You can find this syntax under the "Subset Variables (Columns)" on your Pandas cheat sheet!
#
# With the `analysis_column` variable from above, use Python to display only the column you're analyzing.  This will make it easy to see what the two options were for your question:

# %%
df[[analysis_column]]
# Out:
#     Do you prefer to shower at night or in the morning?
# 0                                Shower in the morning
# 1                                Shower in the morning
# 2                                      Shower at night
# 3                                      Shower at night
# 4                                Shower in the morning
# ..                                                 ...
# 960                              Shower in the morning
# 961                              Shower in the morning
# 962                                    Shower at night
# 963                                    Shower at night
# 964                                    Shower at night
#
# [965 rows x 1 columns]

# %% [markdown]
# ## DataFrame: Group One
#
# Create a DataFrame, `df1`, that contains everyone who picked the first option of your two answers.  *(Make sure to make this a subset of the original `df`, and not just your one column.)*

# %%
df1 = df[df[analysis_column] == "Shower in the morning"]
df1
# Out:
#                        Name Section  \
# 0               Prof. Karle  L1, L2
# 1                Prof. Wade  L1, L2
# 4                    Ayden      Y14
# 6                     Suvan     Y22
# 7                Joseph Kim     Y16
# ..                      ...     ...
# 954                   Junyu  \t Y36
# 955                lijiajin     Y01
# 959                    Zoe      Y19
# 960  Mohammed Fatheen Ahmed     Y22
# 961                   Peter     Y09
#
#     Does your NetID ending with odd number or even number?  \
# 0                        NetID ends with an odd number
# 1                                                  NaN
# 4                       NetID ends with an even number
# 6                       NetID ends with an even number
# 7                       NetID ends with an even number
# ..                                                 ...
# 954                      NetID ends with an odd number
# 955                      NetID ends with an odd number
# 959                     NetID ends with an even number
# 960                      NetID ends with an odd number
# 961                     NetID ends with an even number
#
#     If I flipped a coin, do you think it would it land on heads or tails?  \
# 0                                                Heads
# 1                                                Heads
# 4                                                Heads
# 6                                                Heads
# 7                                                Heads
# ..                                                 ...
# 954                                              Heads
# 955                                              Heads
# 959                                              Heads
# 960                                              Heads
# 961                                              Heads
#
#     Do you like to eat tacos or donuts?  Pick a Number: 0 or 1  \
# 0                                 Tacos                    0.0
# 1                                 Tacos                    1.0
# 4                                Donuts                    1.0
# 6                                Donuts                    1.0
# 7                                Donuts                    1.0
# ..                                  ...                    ...
# 954                               Tacos                    1.0
# 955                              Donuts                    0.0
# 959                               Tacos                    1.0
# 960                              Donuts                    0.0
# 961                               Tacos                    1.0
#
#     Are you a freshman in college? Are you a morning or a night person?  \
# 0                   Not a Freshman                         Night Person
# 1                   Not a Freshman                         Night Person
# 4              Freshman in College                         Night Person
# 6              Freshman in College                         Night Person
# 7                   Not a Freshman                         Night Person
# ..                             ...                                  ...
# 954            Freshman in College                         Night Person
# 955                 Not a Freshman                         Night Person
# 959            Freshman in College                         Night Person
# 960            Freshman in College                       Morning Person
# 961                 Not a Freshman                       Morning Person
#
#     Are you a morning or an afternoon person?  \
# 0                            Afternoon Person
# 1                            Afternoon Person
# 4                              Morning Person
# 6                            Afternoon Person
# 7                            Afternoon Person
# ..                                        ...
# 954                          Afternoon Person
# 955                            Morning Person
# 959                          Afternoon Person
# 960                            Morning Person
# 961                            Morning Person
#
#     Are you a student from Illinois or out-of-state?  ...  \
# 0                                           Illinois  ...
# 1                                                NaN  ...
# 4                                           Illinois  ...
# 6                                           Illinois  ...
# 7                                           Illinois  ...
# ..                                               ...  ...
# 954                                     Out-of-state  ...
# 955                                     Out-of-state  ...
# 959                                         Illinois  ...
# 960                                         Illinois  ...
# 961                                     Out-of-state  ...
#
#     What lab section are you enrolled in? (Use the three-letter code that starts with a "Y", like "Y42".)  \
# 0                                               L1, L2
# 1                                               L1, L2
# 4                                                  Y14
# 6                                                  Y22
# 7                                                  Y16
# ..                                                 ...
# 954                                             \t Y36
# 955                                                Y01
# 959                                                Y19
# 960                                                Y22
# 961                                                Y09
#
#     The level of spiciness you're comfortable with (None, mild, moderate, strong, extreme)?  \
# 0                                             moderate
# 1                                             Moderate
# 4                                               Strong
# 6                                               Strong
# 7                                                 Mild
# ..                                                 ...
# 954                                             strong
# 955                                             strong
# 959                                          Moderate
# 960                                             strong
# 961                                             strong
#
#     What college is your intended major in?  (This is where you hope to end up, not necessarily your current major.)  \
# 0                                           Statistics
# 1                                             Grainger
# 4                                                 Gies
# 6                      Statistics and Computer Science
# 7                                                  LAS
# ..                                                 ...
# 954                               information science
# 955                                                 cs
# 959                              School of Information
# 960                                                las
# 961                                                 CS
#
#     What do you think is the hardest major at UIUC?  \
# 0                             Anything in GRAINGER!
# 1                                           Physics
# 4                                   Any engineering
# 6                              Computer Engineering
# 7                                  Computer Science
# ..                                              ...
# 954                                              CS
# 955                                              cs
# 959                          Molecular engineering
# 960                                              CS
# 961                                              CS
#
#     What genre of music do you listen to? Who is your favorite music artist?  \
# 0                           TAYLOR SWIFT!                       Taylor Swift
# 1                             Pop and EDM                       Taylor Swift
# 4                               Indie pop                      The Lumineers
# 6                                 Hip hop                        Don toliver
# 7                              soundtrack             Ski Mask the Slump God
# ..                                    ...                                ...
# 954                                Hiphop                Tyler, The Creator
# 955                                   sad                           Lana Ray
# 959   Everything (pop, R&B, rap, country)                      Taylor Swift
# 960                                   rap                              Drake
# 961                                  Jazz                                 Ye
#
#     What's your favorite social media app? How do you respond to I-L-L?  \
# 0                                Instagram                        I-N-I
# 1                                  YouTube                        I-N-I
# 4                                 Snapchat                          INI
# 6                                   Tiktok                         Ini
# 7                                Instagram                    I-N-O-I-S
# ..                                     ...                          ...
# 954                                    Ins                         good
# 955                                    ins                        I-N-N
# 959                                Tiktok                        I-N-I!
# 960                                   Snap                         ini
# 961                                     QQ                         illi
#
#     What is your favorite game to play (either video game or IRL)?  \
# 0                                Any type of card game
# 1                                             Factorio
# 4                                           Basketball
# 6                                         20 questions
# 7    Super Smash Bros. Ultimate (Dear Karle and Wad...
# ..                                                 ...
# 954                                             Soccer
# 955                                           valorant
# 959                                   Street Fighters
# 960                                       apex legends
# 961                                     Clash of clans
#
#     What is your dream vacation location?
# 0                            The Maldives
# 1                               Mountains
# 4                              Australia
# 6                             Switzerland
# 7                                 Nowhere
# ..                                    ...
# 954                          Sanya, China
# 955                               finland
# 959                               Greece
# 960                                europe
# 961                               Iceland
#
# [327 rows x 180 columns]

# %% [markdown]
# ## DataFrame: Group Two
#
# Create a new DataFrame, `df2`, that contains everyone who picked the other answer:

# %%
df2 = df[df[analysis_column] == "Shower at night"]
df2
# Out:
#                 Name Section  \
# 2             Andrew     Y05
# 3           Annabel      Y05
# 5               Sens     Y30
# 8              Sarah     Y36
# 9    Pradnyan Khodke     Y24
# ..               ...     ...
# 956          Fabian      Y11
# 957          Arseniy     Y20
# 962            Nyssa     Y23
# 963           maddax      Y2
# 964       CA Sangjun     Y23
#
#     Does your NetID ending with odd number or even number?  \
# 2                        NetID ends with an odd number
# 3                       NetID ends with an even number
# 5                       NetID ends with an even number
# 8                        NetID ends with an odd number
# 9                        NetID ends with an odd number
# ..                                                 ...
# 956                      NetID ends with an odd number
# 957                                                NaN
# 962                      NetID ends with an odd number
# 963                      NetID ends with an odd number
# 964                     NetID ends with an even number
#
#     If I flipped a coin, do you think it would it land on heads or tails?  \
# 2                                                Heads
# 3                                                Heads
# 5                                                Heads
# 8                                                Heads
# 9                                                Heads
# ..                                                 ...
# 956                                              Tails
# 957                                              Heads
# 962                                              Heads
# 963                                              Tails
# 964                                              Heads
#
#     Do you like to eat tacos or donuts?  Pick a Number: 0 or 1  \
# 2                                 Tacos                    1.0
# 3                                 Tacos                    0.0
# 5                                 Tacos                    1.0
# 8                                Donuts                    0.0
# 9                                 Tacos                    1.0
# ..                                  ...                    ...
# 956                               Tacos                    0.0
# 957                               Tacos                    1.0
# 962                               Tacos                    1.0
# 963                               Tacos                    0.0
# 964                               Tacos                    1.0
#
#     Are you a freshman in college? Are you a morning or a night person?  \
# 2              Freshman in College                         Night Person
# 3                   Not a Freshman                         Night Person
# 5              Freshman in College                         Night Person
# 8              Freshman in College                       Morning Person
# 9                   Not a Freshman                       Morning Person
# ..                             ...                                  ...
# 956                 Not a Freshman                         Night Person
# 957                 Not a Freshman                         Night Person
# 962            Freshman in College                         Night Person
# 963            Freshman in College                         Night Person
# 964                 Not a Freshman                         Night Person
#
#     Are you a morning or an afternoon person?  \
# 2                            Afternoon Person
# 3                            Afternoon Person
# 5                              Morning Person
# 8                              Morning Person
# 9                              Morning Person
# ..                                        ...
# 956                          Afternoon Person
# 957                          Afternoon Person
# 962                          Afternoon Person
# 963                          Afternoon Person
# 964                            Morning Person
#
#     Are you a student from Illinois or out-of-state?  ...  \
# 2                                       Out-of-state  ...
# 3                                           Illinois  ...
# 5                                           Illinois  ...
# 8                                           Illinois  ...
# 9                                           Illinois  ...
# ..                                               ...  ...
# 956                                         Illinois  ...
# 957                                     Out-of-state  ...
# 962                                         Illinois  ...
# 963                                         Illinois  ...
# 964                                     Out-of-state  ...
#
#     What lab section are you enrolled in? (Use the three-letter code that starts with a "Y", like "Y42".)  \
# 2                                                  Y05
# 3                                                  Y05
# 5                                                  Y30
# 8                                                  Y36
# 9                                                  Y24
# ..                                                 ...
# 956                                                Y11
# 957                                                Y20
# 962                                                Y23
# 963                                                 Y2
# 964                                                Y23
#
#     The level of spiciness you're comfortable with (None, mild, moderate, strong, extreme)?  \
# 2                                             moderate
# 3                                             Moderate
# 5                                             Moderate
# 8                                               Strong
# 9                                               Strong
# ..                                                 ...
# 956                                           Extreme
# 957                                           moderate
# 962                                               mild
# 963                                            extreme
# 964                                               Mild
#
#     What college is your intended major in?  (This is where you hope to end up, not necessarily your current major.)  \
# 2                                                  LAS
# 3                                     ISchool and LAS
# 5                                     Grainger and LAS
# 8                                              iSchool
# 9                                                  LAS
# ..                                                 ...
# 956                                                 IS
# 957                                                NaN
# 962                                                las
# 963                          finance with data science
# 964                                         Statistics
#
#     What do you think is the hardest major at UIUC?  \
# 2                                                CS
# 3                                 Computer science
# 5                                               ECE
# 8                                  Computer Science
# 9                                               ECE
# ..                                              ...
# 956                               Computer science
# 957                                             NaN
# 962                                             ece
# 963                                         general
# 964                                     Engineering
#
#     What genre of music do you listen to? Who is your favorite music artist?  \
# 2                                     rap                               Dave
# 3                              Rap or r&b                            Eminem
# 5                                Shoegaze                        Fiona Apple
# 8                                   Indie                       Taylor Swift
# 9              Hip hop, R&B, Indie, Rock,                  Tyler The Creator
# ..                                    ...                                ...
# 956                                   Rap                              Drake
# 957                                   NaN                                NaN
# 962                                   pop                       taylor swift
# 963                                   rap                       lil uzi vert
# 964                                   RnB                      Wave to Earth
#
#     What's your favorite social media app? How do you respond to I-L-L?  \
# 2                                instagram                        I-N-I
# 3                                Snapchat                           INI
# 5                                  Twitter                        I-N-I
# 8                                Instagram                        I-N-I
# 9                                        X                        I-N-I
# ..                                     ...                          ...
# 956                                      X                        I-N-I
# 957                                    NaN                        I-N-I
# 962                                twitter                          INI
# 963                               snapchat                          ini
# 964                              Instagram                          INI
#
#     What is your favorite game to play (either video game or IRL)?  \
# 2                                               soccer
# 3                             Volleyball or fortnight
# 5                                            Fall Guys
# 8                                                  Uno
# 9                                           Basketball
# ..                                                 ...
# 956                                          Valorant
# 957                                                NaN
# 962                                         code names
# 963                                        quiet game
# 964                                     Clash of Clans
#
#     What is your dream vacation location?
# 2                                  Hawaii
# 3                                 Greece
# 5                                      PR
# 8                                  Taiwan
# 9                                    Asia
# ..                                    ...
# 956                                Greece
# 957                        Moscow, Russia
# 962                                greece
# 963                    middle of nowhere
# 964                                 Korea
#
# [629 rows x 180 columns]

# %% [markdown]
# ## Analysis
#
# Discuss the following questions with your group and then write down your response!

# %% [markdown]
# **Q1: What percentage of people chose each of your two binary options?**

# %%
629/965
# Out:
# 0.6518134715025907

# %%
327/965
# Out:
# 0.338860103626943

# %% [markdown]
# 629/965 (65.1%) chose shower in the morning and 327/965 (33.8%) chose shower at night

# %% [markdown]
# **Q2: Did this surprise you? Why or why not? Write at least one complete sentence.**

# %% [markdown]
# Not really, showering in the morning is more common in my experience.

# %% [markdown]
# **Q3: Do you think your question was the closest to a perfect 50/50 split among the whole class?**

# %% [markdown]
# No way

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# ## Part 2: Creating Treatment and Control Groups
#
# For the rest of this lab, we will consider the "Hello Dataset" to be a pre-survey of randomly selected participants for an upcoming experiment.  In lecture, you learned that a good experiment will split the participants into two groups: the "treatment" group and the "control" group.
#
# Recall that it is necessary to have both groups:
#
# - The "control" group is a comparison group that will receive a placebo and will act as a control to ensure that the treatment has an effect.
# - The "treatment" group will receive a treatment and we will look for differences between the results of this treatment group and the control group.

# %% [markdown]
# ## Part 2.1: Select a Treatment Group
#
# Select half (50%) of the participants from our original `df` to be in the treatment group and place them into a DataFrame called `treatment`.
# - Remember, you can ask your CAs, TAs, or use your **pandas cheat sheet** to help you out!

# %%
treatment = df.sample(frac=0.5)
treatment
# Out:
#          Name Section Does your NetID ending with odd number or even number?  \
# 460     Alex      Y05                      NetID ends with an odd number
# 359     Daksh     Y30                     NetID ends with an even number
# 661     Kelly     Y04                      NetID ends with an odd number
# 117    Joshua     Y01                     NetID ends with an even number
# 171  Sidharth     Y27                      NetID ends with an odd number
# ..        ...     ...                                                ...
# 239      Abby     Y12                     NetID ends with an even number
# 664      Jeff     Y29                      NetID ends with an odd number
# 472      Emin     Y25                      NetID ends with an odd number
# 167      Aron     Y04                      NetID ends with an odd number
# 703   Junlong     Y15                      NetID ends with an odd number
#
#     If I flipped a coin, do you think it would it land on heads or tails?  \
# 460                                                NaN
# 359                                              Heads
# 661                                              Heads
# 117                                              Heads
# 171                                              Tails
# ..                                                 ...
# 239                                              Heads
# 664                                              Heads
# 472                                              Heads
# 167                                              Heads
# 703                                              Tails
#
#     Do you like to eat tacos or donuts?  Pick a Number: 0 or 1  \
# 460                               Tacos                    1.0
# 359                              Donuts                    0.0
# 661                              Donuts                    1.0
# 117                              Donuts                    0.0
# 171                               Tacos                    1.0
# ..                                  ...                    ...
# 239                              Donuts                    1.0
# 664                              Donuts                    0.0
# 472                               Tacos                    1.0
# 167                               Tacos                    1.0
# 703                               Tacos                    1.0
#
#     Are you a freshman in college? Are you a morning or a night person?  \
# 460                            NaN                         Night Person
# 359            Freshman in College                       Morning Person
# 661                 Not a Freshman                         Night Person
# 117                 Not a Freshman                         Night Person
# 171            Freshman in College                         Night Person
# ..                             ...                                  ...
# 239            Freshman in College                       Morning Person
# 664            Freshman in College                         Night Person
# 472            Freshman in College                       Morning Person
# 167            Freshman in College                       Morning Person
# 703            Freshman in College                       Morning Person
#
#     Are you a morning or an afternoon person?  \
# 460                            Morning Person
# 359                            Morning Person
# 661                          Afternoon Person
# 117                          Afternoon Person
# 171                          Afternoon Person
# ..                                        ...
# 239                            Morning Person
# 664                          Afternoon Person
# 472                            Morning Person
# 167                            Morning Person
# 703                            Morning Person
#
#     Are you a student from Illinois or out-of-state?  ...  \
# 460                                         Illinois  ...
# 359                                     Out-of-state  ...
# 661                                         Illinois  ...
# 117                                         Illinois  ...
# 171                                         Illinois  ...
# ..                                               ...  ...
# 239                                     Out-of-state  ...
# 664                                         Illinois  ...
# 472                                         Illinois  ...
# 167                                     Out-of-state  ...
# 703                                         Illinois  ...
#
#     What lab section are you enrolled in? (Use the three-letter code that starts with a "Y", like "Y42".)  \
# 460                                                Y05
# 359                                                Y30
# 661                                                Y04
# 117                                                Y01
# 171                                                Y27
# ..                                                 ...
# 239                                                Y12
# 664                                                Y29
# 472                                                Y25
# 167                                                Y04
# 703                                                Y15
#
#     The level of spiciness you're comfortable with (None, mild, moderate, strong, extreme)?  \
# 460                                               mild
# 359                                             Strong
# 661                                           Moderate
# 117                                               mild
# 171                                             Strong
# ..                                                 ...
# 239                                           moderate
# 664                                             strong
# 472                                              Mild
# 167                                             Strong
# 703                                            extreme
#
#     What college is your intended major in?  (This is where you hope to end up, not necessarily your current major.)  \
# 460                                               Gies
# 359                                      Econometrics
# 661                                            iSchool
# 117                                                LAS
# 171                                                LAS
# ..                                                 ...
# 239                                               Gies
# 664                                                LAS
# 472                                               Gies
# 167                   Acounting and finance + Data sci
# 703                                            finance
#
#     What do you think is the hardest major at UIUC?  \
# 460                                              cs
# 359                                              CS
# 661                                     Engineering
# 117                                Bio Engineering
# 171                            Computer Engineering
# ..                                              ...
# 239                                     engineering
# 664                                            Math
# 472                                              CS
# 167                                            Math
# 703                                              cs
#
#     What genre of music do you listen to? Who is your favorite music artist?  \
# 460                                  rap                               lucki
# 359                           Everything                  Himesh Reshammiya
# 661                                   Pop                       Taylor Swift
# 117            Everything but heavy metal                  Hoshimachi Suisei
# 171                                   Rap                        Tame Impala
# ..                                    ...                                ...
# 239                                   NaN                                NaN
# 664                                 j-pop                               LiSA
# 472                               Hip-hop                          Pop smoke
# 167                                   Rap                              Drake
# 703                                hippop                              kanye
#
#     What's your favorite social media app? How do you respond to I-L-L?  \
# 460                              instagram                          ini
# 359                             Instagram                         I-N-I
# 661                                 TikTok                        I-N-I
# 117       Twitter (I will never call it X)                        I-N-I
# 171                                 TikTok                          INI
# ..                                     ...                          ...
# 239                               Snapchat                        I-N-I
# 664                                discord                are you sick?
# 472                              Instagram                        I-N-I
# 167                               Snapchat                         INNI
# 703                                 wechat                   don't know
#
#     What is your favorite game to play (either video game or IRL)?  \
# 460                                                gta
# 359                                             Soccer
# 661                                           Valorant
# 117                                           Valorant
# 171                                           Valorant
# ..                                                 ...
# 239                                                NaN
# 664                                            Genshin
# 472                                               Fifa
# 167                                             soccer
# 703                                                gta
#
#     What is your dream vacation location?
# 460                                hawaii
# 359                                Norway
# 661                               Bahamas
# 117                        Korea or Japan
# 171                                 Italy
# ..                                    ...
# 239                                Europe
# 664                               my home
# 472                               Hawaii
# 167                               Germany
# 703                                    CA
#
# [482 rows x 180 columns]

# %% [markdown]
# ## Part 2.2: Select a Control Group
#
# Using the **exact same technique and syntax** as you did above, also select half (50%) of the participants to be in the control group.  Place them into a DataFrame called `control`. For now, it's okay if there are people who are in both groups.

# %%
control = df.sample(frac=0.5)
control
# Out:
#           Name Section Does your NetID ending with odd number or even number?  \
# 462  Christian     Y02                      NetID ends with an odd number
# 400      Kayla     Y18                      NetID ends with an odd number
# 333     Lening     Y02                     NetID ends with an even number
# 706      Ziyao     Y35                      NetID ends with an odd number
# 573        Sam     Y11                     NetID ends with an even number
# ..         ...     ...                                                ...
# 3     Annabel      Y05                     NetID ends with an even number
# 481     Austin     Y11                      NetID ends with an odd number
# 725     Yuxuan      Y1                     NetID ends with an even number
# 384       Jack     Y19                      NetID ends with an odd number
# 517    Jesslyn     Y23                     NetID ends with an even number
#
#     If I flipped a coin, do you think it would it land on heads or tails?  \
# 462                                              Heads
# 400                                              Tails
# 333                                              Heads
# 706                                              Heads
# 573                                              Heads
# ..                                                 ...
# 3                                                Heads
# 481                                              Heads
# 725                                              Heads
# 384                                              Tails
# 517                                              Heads
#
#     Do you like to eat tacos or donuts?  Pick a Number: 0 or 1  \
# 462                               Tacos                    0.0
# 400                              Donuts                    0.0
# 333                               Tacos                    0.0
# 706                               Tacos                    0.0
# 573                               Tacos                    1.0
# ..                                  ...                    ...
# 3                                 Tacos                    0.0
# 481                               Tacos                    0.0
# 725                              Donuts                    0.0
# 384                               Tacos                    0.0
# 517                               Tacos                    1.0
#
#     Are you a freshman in college? Are you a morning or a night person?  \
# 462                 Not a Freshman                       Morning Person
# 400            Freshman in College                         Night Person
# 333                 Not a Freshman                         Night Person
# 706            Freshman in College                         Night Person
# 573                 Not a Freshman                         Night Person
# ..                             ...                                  ...
# 3                   Not a Freshman                         Night Person
# 481                 Not a Freshman                         Night Person
# 725            Freshman in College                       Morning Person
# 384                 Not a Freshman                         Night Person
# 517            Freshman in College                       Morning Person
#
#     Are you a morning or an afternoon person?  \
# 462                            Morning Person
# 400                          Afternoon Person
# 333                          Afternoon Person
# 706                          Afternoon Person
# 573                          Afternoon Person
# ..                                        ...
# 3                            Afternoon Person
# 481                          Afternoon Person
# 725                          Afternoon Person
# 384                          Afternoon Person
# 517                            Morning Person
#
#     Are you a student from Illinois or out-of-state?  ...  \
# 462                                         Illinois  ...
# 400                                         Illinois  ...
# 333                                     Out-of-state  ...
# 706                                     Out-of-state  ...
# 573                                         Illinois  ...
# ..                                               ...  ...
# 3                                           Illinois  ...
# 481                                         Illinois  ...
# 725                                         Illinois  ...
# 384                                         Illinois  ...
# 517                                     Out-of-state  ...
#
#     What lab section are you enrolled in? (Use the three-letter code that starts with a "Y", like "Y42".)  \
# 462                                                Y02
# 400                                                Y18
# 333                                                Y02
# 706                                                Y35
# 573                                                Y11
# ..                                                 ...
# 3                                                  Y05
# 481                                                Y11
# 725                                                 Y1
# 384                                                Y19
# 517                                                Y23
#
#     The level of spiciness you're comfortable with (None, mild, moderate, strong, extreme)?  \
# 462                                           Moderate
# 400                                               Mild
# 333                                            extreme
# 706                                               mild
# 573                                           moderate
# ..                                                 ...
# 3                                             Moderate
# 481                                               mild
# 725                                           moderate
# 384                                           moderate
# 517                                             strong
#
#     What college is your intended major in?  (This is where you hope to end up, not necessarily your current major.)  \
# 462                                            iSchool
# 400         Math w/ Concentration in Data Optimization
# 333                                                LAS
# 706                             electrical engineering
# 573                                      College of IS
# ..                                                 ...
# 3                                     ISchool and LAS
# 481                                           Grainger
# 725                                           Grainger
# 384                 Information Science + Data Science
# 517                                       Finance + DS
#
#     What do you think is the hardest major at UIUC?  \
# 462                                  Bioengineering
# 400                                Computer Science
# 333                                              CS
# 706                                              CS
# 573                                Computer Science
# ..                                              ...
# 3                                 Computer science
# 481                            Computer Engineering
# 725                                             ECE
# 384                                              CS
# 517                                  bioengineering
#
#     What genre of music do you listen to? Who is your favorite music artist?  \
# 462                            Electronic                      Macross 82-99
# 400                              Pop punk                           Paramore
# 333                                   R&B                            Galdive
# 706                           Vapour wave                           Jay Chou
# 573                            Everything                         Zach Bryan
# ..                                    ...                                ...
# 3                              Rap or r&b                            Eminem
# 481                                   Any                            MF Doom
# 725                                   R&B                       Taylor Swift
# 384                                  Rock                        The Beetles
# 517                                   pop                       Benson Boone
#
#     What's your favorite social media app? How do you respond to I-L-L?  \
# 462                              Instagram                        I-N-I
# 400                               Snapchat                        I-N-I
# 333                              Instagram                          INI
# 706                                 wechat                         none
# 573                              Instagram                        I-N-I
# ..                                     ...                          ...
# 3                                Snapchat                           INI
# 481                              Instagram                          INI
# 725                                discord                            I
# 384                                 TikTok                          INI
# 517                              Instagram                          INI
#
#     What is your favorite game to play (either video game or IRL)?  \
# 462                                      Battlefield 4
# 400                                        Monopoly Go
# 333                                       It takes two
# 706                                                IRL
# 573                                          Madden 23
# ..                                                 ...
# 3                             Volleyball or fortnight
# 481                                          Overwatch
# 725                                                LoL
# 384                                              Katan
# 517                                               none
#
#     What is your dream vacation location?
# 462                             Singapore
# 400                               Bahamas
# 333                             Australia
# 706                               Iceland
# 573                               Iceland
# ..                                    ...
# 3                                 Greece
# 481                                 Japan
# 725                                 Hawai
# 384                           Netherlands
# 517                                  Bali
#
# [482 rows x 180 columns]

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == CHECKPOINT TEST CASES ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any error in your output, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
assert( 'df' in vars() ), "You do not have a DataFrame called `df`."
assert( 'treatment' in vars() ), "You do not have a DataFrame called `treatment`."
assert( 'control' in vars() ), "You do not have a DataFrame called `control`."
assert( len(treatment) == len(control) ), "The `treatment` and `control` groups must be the same size."
assert( abs((len(df) / 2) - len(treatment)) <= 1 ), "The `treatment` group size must be 50% of the `df`"
assert( abs((len(df) / 2) - len(control)) <= 1 ), "The `control` group size must be 50% of the `df`"


## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ## Analysis: Overlapping Selection?
#
# The following code will detect rows that are **both in your treatment and control** groups.
#
# Run the following cell to see everyone who is in both groups:

# %%
df[ df.index.isin(treatment.index) & df.index.isin(control.index) ]
# Out:
#             Name Section  \
# 0    Prof. Karle  L1, L2
# 15       Michael     Y03
# 17        Chuyan     Y24
# 18       Jackson     Y21
# 20         Eric      Y10
# ..           ...     ...
# 942        Billy     Y29
# 945       Jenny      Y01
# 947     Maximoff     Y33
# 952         Erin     Y29
# 953        Laura     Y28
#
#     Does your NetID ending with odd number or even number?  \
# 0                        NetID ends with an odd number
# 15                      NetID ends with an even number
# 17                      NetID ends with an even number
# 18                      NetID ends with an even number
# 20                       NetID ends with an odd number
# ..                                                 ...
# 942                     NetID ends with an even number
# 945                     NetID ends with an even number
# 947                      NetID ends with an odd number
# 952                      NetID ends with an odd number
# 953                     NetID ends with an even number
#
#     If I flipped a coin, do you think it would it land on heads or tails?  \
# 0                                                Heads
# 15                                               Heads
# 17                                               Heads
# 18                                               Tails
# 20                                               Heads
# ..                                                 ...
# 942                                              Heads
# 945                                              Heads
# 947                                              Tails
# 952                                              Heads
# 953                                              Heads
#
#     Do you like to eat tacos or donuts?  Pick a Number: 0 or 1  \
# 0                                 Tacos                    0.0
# 15                                Tacos                    0.0
# 17                               Donuts                    0.0
# 18                                Tacos                    1.0
# 20                                Tacos                    1.0
# ..                                  ...                    ...
# 942                               Tacos                    1.0
# 945                               Tacos                    1.0
# 947                               Tacos                    0.0
# 952                               Tacos                    1.0
# 953                              Donuts                    0.0
#
#     Are you a freshman in college? Are you a morning or a night person?  \
# 0                   Not a Freshman                         Night Person
# 15                  Not a Freshman                         Night Person
# 17             Freshman in College                         Night Person
# 18             Freshman in College                         Night Person
# 20             Freshman in College                         Night Person
# ..                             ...                                  ...
# 942            Freshman in College                         Night Person
# 945            Freshman in College                         Night Person
# 947                 Not a Freshman                         Night Person
# 952            Freshman in College                       Morning Person
# 953            Freshman in College                         Night Person
#
#     Are you a morning or an afternoon person?  \
# 0                            Afternoon Person
# 15                           Afternoon Person
# 17                           Afternoon Person
# 18                           Afternoon Person
# 20                           Afternoon Person
# ..                                        ...
# 942                          Afternoon Person
# 945                          Afternoon Person
# 947                          Afternoon Person
# 952                          Afternoon Person
# 953                          Afternoon Person
#
#     Are you a student from Illinois or out-of-state?  ...  \
# 0                                           Illinois  ...
# 15                                          Illinois  ...
# 17                                      Out-of-state  ...
# 18                                          Illinois  ...
# 20                                          Illinois  ...
# ..                                               ...  ...
# 942                                         Illinois  ...
# 945                                     Out-of-state  ...
# 947                                         Illinois  ...
# 952                                         Illinois  ...
# 953                                     Out-of-state  ...
#
#     What lab section are you enrolled in? (Use the three-letter code that starts with a "Y", like "Y42".)  \
# 0                                               L1, L2
# 15                                                 Y03
# 17                                                 Y24
# 18                                                 Y21
# 20                                                 Y10
# ..                                                 ...
# 942                                                Y29
# 945                                                Y01
# 947                                                Y33
# 952                                                Y29
# 953                                                Y28
#
#     The level of spiciness you're comfortable with (None, mild, moderate, strong, extreme)?  \
# 0                                             moderate
# 15                                             Extreme
# 17                                             extreme
# 18                                            Moderate
# 20                                           Moderate
# ..                                                 ...
# 942                                             strong
# 945                                                NaN
# 947                                             Strong
# 952                                             strong
# 953                                             Strong
#
#     What college is your intended major in?  (This is where you hope to end up, not necessarily your current major.)  \
# 0                                           Statistics
# 15                                                 LAS
# 17                                            business
# 18                                                Gies
# 20                                         Accounting
# ..                                                 ...
# 942                                                LAS
# 945                                                NaN
# 947                                                LAS
# 952                                               UIUC
# 953                                               Gies
#
#     What do you think is the hardest major at UIUC?  \
# 0                             Anything in GRAINGER!
# 15                           Electrical Engineering
# 17                                               CS
# 18                                      Engineering
# 20                                     Engineering
# ..                                              ...
# 942                               Computer science
# 945                                             NaN
# 947                            chemical engineering
# 952                                              CS
# 953                                    Engineering
#
#     What genre of music do you listen to? Who is your favorite music artist?  \
# 0                           TAYLOR SWIFT!                       Taylor Swift
# 15                             Indie rock                           Pavement
# 17                                    R&B                           Jay Chou
# 18                                Country                      Morgan Wallen
# 20                                    R&B                               Joji
# ..                                    ...                                ...
# 942                                   Rap                             Polo g
# 945                                   NaN                                NaN
# 947       hip-hop, r&b, rock, heavy metal                              JIHYO
# 952          R&B, Indie music, pop, K-pop                       Shawn Mendes
# 953                                   Pop                         Eason Chen
#
#     What's your favorite social media app? How do you respond to I-L-L?  \
# 0                                Instagram                        I-N-I
# 15                               Instagram                        I-N-I
# 17                                  Wechat                    Illinois?
# 18                                Snapchat                          INI
# 20                                  TikTok                        INOIS
# ..                                     ...                          ...
# 942                                 Tiktok                          INI
# 945                                    NaN                          NaN
# 947                                Twitter                           🧡💙
# 952                              instagram                        I-N-I
# 953                              Instagram                        I-N-I
#
#     What is your favorite game to play (either video game or IRL)?  \
# 0                                Any type of card game
# 15                                            Baseball
# 17                                                none
# 18                                              Soccer
# 20                                           Guess Who
# ..                                                 ...
# 942                                           Lacrosse
# 945                                                NaN
# 947                                               OSU!
# 952                                                IRL
# 953                                               2048
#
#     What is your dream vacation location?
# 0                            The Maldives
# 15                                 France
# 17         travel with friends and family
# 18                                 Hawaii
# 20                                    NaN
# ..                                    ...
# 942                                  Ohio
# 945                                   NaN
# 947                        Cancún, Mexico
# 952                              New York
# 953                                europe
#
# [237 rows x 180 columns]

# %% [markdown]
# **Q: Why would your code result in some people being included in both groups? Write at least one complete sentence explaining why you think this might occur.**

# %% [markdown]
# The sample(frac=0.5) function is choosing from the overall table each time, not selecting the first 50% and then the 2nd 50%

# %% [markdown]
# ## Part 2.3:
#
# Read the following guide on **using `.index.isin` to select all rows from a DataFrame not in another DataFrame**: https://discovery.cs.illinois.edu/guides/DataFrame-Row-Selection/dataframe-isin-selection/
#
# Finally, create a new `control` group that contains all of the participants from `df` that are not in `treatment`:

# %%
control = df[~df.index.isin(treatment.index)]
control
# Out:
#                        Name Section  \
# 2                    Andrew     Y05
# 3                  Annabel      Y05
# 4                    Ayden      Y14
# 5                      Sens     Y30
# 6                     Suvan     Y22
# ..                      ...     ...
# 959                    Zoe      Y19
# 960  Mohammed Fatheen Ahmed     Y22
# 961                   Peter     Y09
# 962                   Nyssa     Y23
# 964              CA Sangjun     Y23
#
#     Does your NetID ending with odd number or even number?  \
# 2                        NetID ends with an odd number
# 3                       NetID ends with an even number
# 4                       NetID ends with an even number
# 5                       NetID ends with an even number
# 6                       NetID ends with an even number
# ..                                                 ...
# 959                     NetID ends with an even number
# 960                      NetID ends with an odd number
# 961                     NetID ends with an even number
# 962                      NetID ends with an odd number
# 964                     NetID ends with an even number
#
#     If I flipped a coin, do you think it would it land on heads or tails?  \
# 2                                                Heads
# 3                                                Heads
# 4                                                Heads
# 5                                                Heads
# 6                                                Heads
# ..                                                 ...
# 959                                              Heads
# 960                                              Heads
# 961                                              Heads
# 962                                              Heads
# 964                                              Heads
#
#     Do you like to eat tacos or donuts?  Pick a Number: 0 or 1  \
# 2                                 Tacos                    1.0
# 3                                 Tacos                    0.0
# 4                                Donuts                    1.0
# 5                                 Tacos                    1.0
# 6                                Donuts                    1.0
# ..                                  ...                    ...
# 959                               Tacos                    1.0
# 960                              Donuts                    0.0
# 961                               Tacos                    1.0
# 962                               Tacos                    1.0
# 964                               Tacos                    1.0
#
#     Are you a freshman in college? Are you a morning or a night person?  \
# 2              Freshman in College                         Night Person
# 3                   Not a Freshman                         Night Person
# 4              Freshman in College                         Night Person
# 5              Freshman in College                         Night Person
# 6              Freshman in College                         Night Person
# ..                             ...                                  ...
# 959            Freshman in College                         Night Person
# 960            Freshman in College                       Morning Person
# 961                 Not a Freshman                       Morning Person
# 962            Freshman in College                         Night Person
# 964                 Not a Freshman                         Night Person
#
#     Are you a morning or an afternoon person?  \
# 2                            Afternoon Person
# 3                            Afternoon Person
# 4                              Morning Person
# 5                              Morning Person
# 6                            Afternoon Person
# ..                                        ...
# 959                          Afternoon Person
# 960                            Morning Person
# 961                            Morning Person
# 962                          Afternoon Person
# 964                            Morning Person
#
#     Are you a student from Illinois or out-of-state?  ...  \
# 2                                       Out-of-state  ...
# 3                                           Illinois  ...
# 4                                           Illinois  ...
# 5                                           Illinois  ...
# 6                                           Illinois  ...
# ..                                               ...  ...
# 959                                         Illinois  ...
# 960                                         Illinois  ...
# 961                                     Out-of-state  ...
# 962                                         Illinois  ...
# 964                                     Out-of-state  ...
#
#     What lab section are you enrolled in? (Use the three-letter code that starts with a "Y", like "Y42".)  \
# 2                                                  Y05
# 3                                                  Y05
# 4                                                  Y14
# 5                                                  Y30
# 6                                                  Y22
# ..                                                 ...
# 959                                                Y19
# 960                                                Y22
# 961                                                Y09
# 962                                                Y23
# 964                                                Y23
#
#     The level of spiciness you're comfortable with (None, mild, moderate, strong, extreme)?  \
# 2                                             moderate
# 3                                             Moderate
# 4                                               Strong
# 5                                             Moderate
# 6                                               Strong
# ..                                                 ...
# 959                                          Moderate
# 960                                             strong
# 961                                             strong
# 962                                               mild
# 964                                               Mild
#
#     What college is your intended major in?  (This is where you hope to end up, not necessarily your current major.)  \
# 2                                                  LAS
# 3                                     ISchool and LAS
# 4                                                 Gies
# 5                                     Grainger and LAS
# 6                      Statistics and Computer Science
# ..                                                 ...
# 959                              School of Information
# 960                                                las
# 961                                                 CS
# 962                                                las
# 964                                         Statistics
#
#     What do you think is the hardest major at UIUC?  \
# 2                                                CS
# 3                                 Computer science
# 4                                   Any engineering
# 5                                               ECE
# 6                              Computer Engineering
# ..                                              ...
# 959                          Molecular engineering
# 960                                              CS
# 961                                              CS
# 962                                             ece
# 964                                     Engineering
#
#     What genre of music do you listen to? Who is your favorite music artist?  \
# 2                                     rap                               Dave
# 3                              Rap or r&b                            Eminem
# 4                               Indie pop                      The Lumineers
# 5                                Shoegaze                        Fiona Apple
# 6                                 Hip hop                        Don toliver
# ..                                    ...                                ...
# 959   Everything (pop, R&B, rap, country)                      Taylor Swift
# 960                                   rap                              Drake
# 961                                  Jazz                                 Ye
# 962                                   pop                       taylor swift
# 964                                   RnB                      Wave to Earth
#
#     What's your favorite social media app? How do you respond to I-L-L?  \
# 2                                instagram                        I-N-I
# 3                                Snapchat                           INI
# 4                                 Snapchat                          INI
# 5                                  Twitter                        I-N-I
# 6                                   Tiktok                         Ini
# ..                                     ...                          ...
# 959                                Tiktok                        I-N-I!
# 960                                   Snap                         ini
# 961                                     QQ                         illi
# 962                                twitter                          INI
# 964                              Instagram                          INI
#
#     What is your favorite game to play (either video game or IRL)?  \
# 2                                               soccer
# 3                             Volleyball or fortnight
# 4                                           Basketball
# 5                                            Fall Guys
# 6                                         20 questions
# ..                                                 ...
# 959                                   Street Fighters
# 960                                       apex legends
# 961                                     Clash of clans
# 962                                         code names
# 964                                     Clash of Clans
#
#     What is your dream vacation location?
# 2                                  Hawaii
# 3                                 Greece
# 4                              Australia
# 5                                      PR
# 6                             Switzerland
# ..                                    ...
# 959                               Greece
# 960                                europe
# 961                               Iceland
# 962                                greece
# 964                                 Korea
#
# [483 rows x 180 columns]

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == CHECKPOINT TEST CASES ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any errors in your output, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
assert( 'df' in vars() ), "You do not have a DataFrame called `df`."
assert( 'treatment' in vars() ), "You do not have a DataFrame called `treatment`."
assert( 'control' in vars() ), "You do not have a DataFrame called `control`."
assert( abs((len(df) / 2) - len(treatment)) <= 1 ), "The `treatment` group size must be 50% of the `df`"
assert( abs((len(df) / 2) - len(control)) <= 1 ), "The `control` group size must be 50% of the `df`"
assert( len(df[ df.index.isin(treatment.index) & df.index.isin(control.index) ]) == 0), "The `treatment` and `control` groups have some overlap!  There must be no overlap."

## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ## Part 2.4: Finding Yourself!
#
# Use the following cells to write Python code to find yourself in either the treatment group or control group.
# - **Hint**: How do you select a subset of rows?  What conditional will identify you??
# - If you did not fill out the "Hello Survey" then you are not in this dataset. :(
# - If you are not in this survey, find either "Prof. Wade" or "Prof. Karle" instead.  *(Those are the names we used in the `Name` column.)*

# %%
treatment[treatment.Name == "Ryan"]
# Out:
#      Name Section Does your NetID ending with odd number or even number?  \
# 12   Ryan     Y30                     NetID ends with an even number
# 816  Ryan     Y23                     NetID ends with an even number
# 122  Ryan     Y31                     NetID ends with an even number
# 675  Ryan     Y12                      NetID ends with an odd number
#
#     If I flipped a coin, do you think it would it land on heads or tails?  \
# 12                                               Heads
# 816                                              Heads
# 122                                              Heads
# 675                                              Heads
#
#     Do you like to eat tacos or donuts?  Pick a Number: 0 or 1  \
# 12                               Donuts                    0.0
# 816                               Tacos                    0.0
# 122                              Donuts                    0.0
# 675                              Donuts                    1.0
#
#     Are you a freshman in college? Are you a morning or a night person?  \
# 12             Freshman in College                         Night Person
# 816                 Not a Freshman                         Night Person
# 122            Freshman in College                       Morning Person
# 675            Freshman in College                         Night Person
#
#     Are you a morning or an afternoon person?  \
# 12                           Afternoon Person
# 816                          Afternoon Person
# 122                            Morning Person
# 675                          Afternoon Person
#
#     Are you a student from Illinois or out-of-state?  ...  \
# 12                                          Illinois  ...
# 816                                         Illinois  ...
# 122                                         Illinois  ...
# 675                                         Illinois  ...
#
#     What lab section are you enrolled in? (Use the three-letter code that starts with a "Y", like "Y42".)  \
# 12                                                 Y30
# 816                                                Y23
# 122                                                Y31
# 675                                                Y12
#
#     The level of spiciness you're comfortable with (None, mild, moderate, strong, extreme)?  \
# 12                                            Moderate
# 816                                             Strong
# 122                                           Moderate
# 675                                             strong
#
#     What college is your intended major in?  (This is where you hope to end up, not necessarily your current major.)  \
# 12                                                 LAS
# 816                                                LAS
# 122                                            iSchool
# 675                                               Gies
#
#     What do you think is the hardest major at UIUC?  \
# 12                                          Physics
# 816                                     Engineering
# 122                                              CS
# 675                                        Bio Chem
#
#     What genre of music do you listen to? Who is your favorite music artist?  \
# 12                                   Rock               Two Door Cinema Club
# 816                                   DnB                         Deathbrain
# 122                                   Pop                           Surfaces
# 675                                   Rap                       Playboi Cart
#
#     What's your favorite social media app? How do you respond to I-L-L?  \
# 12                                 youtube                  **silence**
# 816                                    NaN                          INI
# 122                                YouTube                       Innie!
# 675                                   Snap                          INI
#
#     What is your favorite game to play (either video game or IRL)?  \
# 12                                          Overcooked
# 816                                      Silent Hill 2
# 122                                          Minecraft
# 675                                    Rainbow 6 Seige
#
#     What is your dream vacation location?
# 12              Grand Teton National Park
# 816                      San Juan Islands
# 122                                Hawaii
# 675                                 Italy
#
# [4 rows x 180 columns]

# %% [markdown]
# ## Analysis: Finding Yourself!
#
# **Q: Which group where you in -- treatment or control?**

# %% [markdown]
# Treatment

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# # Part 3: Using Blocking to Create Treatment and Control Groups that are Balanced
#
# In your pre-experiment research, you have reason to believe that how the participants answer **your group's question** might influence the response of this experiment!  Oh no! Even though this is a large sample of participants, we want to block to be absolutely sure that the treatment and control groups are balanced with regard to your group's question!
#
# To control for this, we will using **blocking**!  Remember from lecture that blocking refers to creating subgroups for each response, selecting equal-sized treatment and control groups from each block, and then combining all the treatment groups together and all the control groups together to get the final groups. This ensures that your groups are balanced with regard to the variable you blocked on!
#
# You have already done some of this work:
# - Earlier in this notebook, you created `df1` that includes everyone who answered your group's question one way.
# - Earlier in this notebook, you created `df2` that includes everyone who answered your group's question the other way.

# %% [markdown]
# ## Part 3.1:
#
# Create a `df1_treatment` group that contains a random selection of 50% of the rows from `df1`.

# %%
df1_treatment = df1.sample(frac=0.5)
df1_treatment
# Out:
#          Name Section Does your NetID ending with odd number or even number?  \
# 599  Jeongyun     Y04                      NetID ends with an odd number
# 253   Victor      Y26                     NetID ends with an even number
# 941   Michael     Y29                     NetID ends with an even number
# 354    Landon     Y12                     NetID ends with an even number
# 830  CA Salar     Y26                     NetID ends with an even number
# ..        ...     ...                                                ...
# 875     Tisha     Y14                      NetID ends with an odd number
# 166     Erica     Y08                     NetID ends with an even number
# 255     Orion     Y34                      NetID ends with an odd number
# 245       Ava     Y36                     NetID ends with an even number
# 645        LJ     Y03                     NetID ends with an even number
#
#     If I flipped a coin, do you think it would it land on heads or tails?  \
# 599                                              Heads
# 253                                              Tails
# 941                                              Heads
# 354                                              Tails
# 830                                              Heads
# ..                                                 ...
# 875                                              Heads
# 166                                              Tails
# 255                                              Heads
# 245                                              Heads
# 645                                              Tails
#
#     Do you like to eat tacos or donuts?  Pick a Number: 0 or 1  \
# 599                               Tacos                    0.0
# 253                               Tacos                    1.0
# 941                              Donuts                    1.0
# 354                              Donuts                    1.0
# 830                               Tacos                    0.0
# ..                                  ...                    ...
# 875                               Tacos                    0.0
# 166                              Donuts                    1.0
# 255                              Donuts                    0.0
# 245                               Tacos                    1.0
# 645                               Tacos                    1.0
#
#     Are you a freshman in college? Are you a morning or a night person?  \
# 599                 Not a Freshman                       Morning Person
# 253            Freshman in College                         Night Person
# 941            Freshman in College                         Night Person
# 354            Freshman in College                         Night Person
# 830                 Not a Freshman                         Night Person
# ..                             ...                                  ...
# 875                 Not a Freshman                       Morning Person
# 166                 Not a Freshman                         Night Person
# 255                 Not a Freshman                       Morning Person
# 245                 Not a Freshman                         Night Person
# 645                 Not a Freshman                       Morning Person
#
#     Are you a morning or an afternoon person?  \
# 599                          Afternoon Person
# 253                          Afternoon Person
# 941                          Afternoon Person
# 354                          Afternoon Person
# 830                          Afternoon Person
# ..                                        ...
# 875                          Afternoon Person
# 166                          Afternoon Person
# 255                            Morning Person
# 245                          Afternoon Person
# 645                            Morning Person
#
#     Are you a student from Illinois or out-of-state?  ...  \
# 599                                     Out-of-state  ...
# 253                                         Illinois  ...
# 941                                     Out-of-state  ...
# 354                                         Illinois  ...
# 830                                     Out-of-state  ...
# ..                                               ...  ...
# 875                                     Out-of-state  ...
# 166                                         Illinois  ...
# 255                                         Illinois  ...
# 245                                         Illinois  ...
# 645                                         Illinois  ...
#
#     What lab section are you enrolled in? (Use the three-letter code that starts with a "Y", like "Y42".)  \
# 599                                                Y04
# 253                                                Y26
# 941                                                Y29
# 354                                                Y12
# 830                                                Y26
# ..                                                 ...
# 875                                                Y14
# 166                                                Y08
# 255                                                Y34
# 245                                                Y36
# 645                                                Y03
#
#     The level of spiciness you're comfortable with (None, mild, moderate, strong, extreme)?  \
# 599                                           moderate
# 253                                            Strong
# 941                                             Strong
# 354                                               mild
# 830                                             Strong
# ..                                                 ...
# 875                                               mild
# 166                                                NaN
# 255                                               mild
# 245                                             strong
# 645                                             strong
#
#     What college is your intended major in?  (This is where you hope to end up, not necessarily your current major.)  \
# 599                                         Statistics
# 253                          Gies College of Business
# 941                                               Gies
# 354                                               Gies
# 830                                                LAS
# ..                                                 ...
# 875                                                LAS
# 166                                                LAS
# 255                                                LAS
# 245                                   college of media
# 645                                    Library Science
#
#     What do you think is the hardest major at UIUC?  \
# 599                                Computer Science
# 253                               Computer Science
# 941                                              CS
# 354                           Aerospace Engineering
# 830                                         Physics
# ..                                              ...
# 875                                         physics
# 166                                              CS
# 255                                         Physics
# 245                            anything engineering
# 645                                         Vet Med
#
#     What genre of music do you listen to? Who is your favorite music artist?  \
# 599                                 K-POP                          New Jeans
# 253                           Rap+ HipHop                    Kendrick Lamar
# 941                                   Rap                       Lil Uzi Vert
# 354     All (not country or Taylor Swift)                     Kendrick Lamar
# 830                                   RnB                              Kanye
# ..                                    ...                                ...
# 875                                   rap                                mgk
# 166                                 Indie                    The Crane Wives
# 255                                  Punk                                TX2
# 245                                   pop                         The Weeknd
# 645                           Alternative                            Anarbor
#
#     What's your favorite social media app? How do you respond to I-L-L?  \
# 599                              Instagram                          INI
# 253                                 tiktok                        I-N-I
# 941                                 TikTok                          INI
# 354                                youtube                        I-N-I
# 830                                      X                        I-N-I
# ..                                     ...                          ...
# 875                                  insta                        I-N-I
# 166                                 TikTok                        I-N-I
# 255                                 Tumblr                      I don't
# 245                                tik tok                        I-N-I
# 645                                  Venmo                        I-N-I
#
#     What is your favorite game to play (either video game or IRL)?  \
# 599                                  League of Legends
# 253                                               Uno
# 941                                           Lacrosse
# 354                                        Titanfall 2
# 830                                           Fortnite
# ..                                                 ...
# 875                                         mario kart
# 166                                      Secret Hitler
# 255                                             Skyrim
# 245                                             soccer
# 645                                            Skip-bo
#
#     What is your dream vacation location?
# 599                           Switzerland
# 253                         Tokyo, Japan
# 941                                 Italy
# 354              Lake Geneva, Switzerland
# 830                                  Iowa
# ..                                    ...
# 875                                 japan
# 166                               Germany
# 255                              Scotland
# 245                                 Italy
# 645                               Germany
#
# [164 rows x 180 columns]

# %% [markdown]
# ## Part 3.2:
#
# Create a `df1_control` group that contains the other half of the rows from `df1`. *(You can refer back to Part 2 to refresh on how to do this, make sure you use `df1` and `df1_control` as your DataFrames.)*

# %%
df1_control = df1[~df1.index.isin(df1_treatment.index)]
df1_control
# Out:
#             Name Section  \
# 0    Prof. Karle  L1, L2
# 1     Prof. Wade  L1, L2
# 4         Ayden      Y14
# 7     Joseph Kim     Y16
# 14        George     Y32
# ..           ...     ...
# 939        Riley    Y107
# 949     Vihaansh     Y08
# 954        Junyu  \t Y36
# 955     lijiajin     Y01
# 961        Peter     Y09
#
#     Does your NetID ending with odd number or even number?  \
# 0                        NetID ends with an odd number
# 1                                                  NaN
# 4                       NetID ends with an even number
# 7                       NetID ends with an even number
# 14                      NetID ends with an even number
# ..                                                 ...
# 939                     NetID ends with an even number
# 949                      NetID ends with an odd number
# 954                      NetID ends with an odd number
# 955                      NetID ends with an odd number
# 961                     NetID ends with an even number
#
#     If I flipped a coin, do you think it would it land on heads or tails?  \
# 0                                                Heads
# 1                                                Heads
# 4                                                Heads
# 7                                                Heads
# 14                                               Heads
# ..                                                 ...
# 939                                              Tails
# 949                                              Heads
# 954                                              Heads
# 955                                              Heads
# 961                                              Heads
#
#     Do you like to eat tacos or donuts?  Pick a Number: 0 or 1  \
# 0                                 Tacos                    0.0
# 1                                 Tacos                    1.0
# 4                                Donuts                    1.0
# 7                                Donuts                    1.0
# 14                               Donuts                    1.0
# ..                                  ...                    ...
# 939                               Tacos                    0.0
# 949                               Tacos                    1.0
# 954                               Tacos                    1.0
# 955                              Donuts                    0.0
# 961                               Tacos                    1.0
#
#     Are you a freshman in college? Are you a morning or a night person?  \
# 0                   Not a Freshman                         Night Person
# 1                   Not a Freshman                         Night Person
# 4              Freshman in College                         Night Person
# 7                   Not a Freshman                         Night Person
# 14             Freshman in College                         Night Person
# ..                             ...                                  ...
# 939            Freshman in College                         Night Person
# 949                 Not a Freshman                         Night Person
# 954            Freshman in College                         Night Person
# 955                 Not a Freshman                         Night Person
# 961                 Not a Freshman                       Morning Person
#
#     Are you a morning or an afternoon person?  \
# 0                            Afternoon Person
# 1                            Afternoon Person
# 4                              Morning Person
# 7                            Afternoon Person
# 14                           Afternoon Person
# ..                                        ...
# 939                          Afternoon Person
# 949                          Afternoon Person
# 954                          Afternoon Person
# 955                            Morning Person
# 961                            Morning Person
#
#     Are you a student from Illinois or out-of-state?  ...  \
# 0                                           Illinois  ...
# 1                                                NaN  ...
# 4                                           Illinois  ...
# 7                                           Illinois  ...
# 14                                      Out-of-state  ...
# ..                                               ...  ...
# 939                                         Illinois  ...
# 949                                     Out-of-state  ...
# 954                                     Out-of-state  ...
# 955                                     Out-of-state  ...
# 961                                     Out-of-state  ...
#
#     What lab section are you enrolled in? (Use the three-letter code that starts with a "Y", like "Y42".)  \
# 0                                               L1, L2
# 1                                               L1, L2
# 4                                                  Y14
# 7                                                  Y16
# 14                                                 Y32
# ..                                                 ...
# 939                                               Y107
# 949                                                Y08
# 954                                             \t Y36
# 955                                                Y01
# 961                                                Y09
#
#     The level of spiciness you're comfortable with (None, mild, moderate, strong, extreme)?  \
# 0                                             moderate
# 1                                             Moderate
# 4                                               Strong
# 7                                                 Mild
# 14                                              strong
# ..                                                 ...
# 939                                           moderate
# 949                                            Extreme
# 954                                             strong
# 955                                             strong
# 961                                             strong
#
#     What college is your intended major in?  (This is where you hope to end up, not necessarily your current major.)  \
# 0                                           Statistics
# 1                                             Grainger
# 4                                                 Gies
# 7                                                  LAS
# 14                              University of Colombia
# ..                                                 ...
# 939                                                las
# 949                               Computer Engineering
# 954                               information science
# 955                                                 cs
# 961                                                 CS
#
#     What do you think is the hardest major at UIUC?  \
# 0                             Anything in GRAINGER!
# 1                                           Physics
# 4                                   Any engineering
# 7                                  Computer Science
# 14                                             Math
# ..                                              ...
# 939                                       chemistry
# 949                          Electrical Engineering
# 954                                              CS
# 955                                              cs
# 961                                              CS
#
#     What genre of music do you listen to? Who is your favorite music artist?  \
# 0                           TAYLOR SWIFT!                       Taylor Swift
# 1                             Pop and EDM                       Taylor Swift
# 4                               Indie pop                      The Lumineers
# 7                              soundtrack             Ski Mask the Slump God
# 14                           instrumental                           HOYO-MiX
# ..                                    ...                                ...
# 939                           rap and pop                              drake
# 949                                  Rock                             Eminem
# 954                                Hiphop                Tyler, The Creator
# 955                                   sad                           Lana Ray
# 961                                  Jazz                                 Ye
#
#     What's your favorite social media app? How do you respond to I-L-L?  \
# 0                                Instagram                        I-N-I
# 1                                  YouTube                        I-N-I
# 4                                 Snapchat                          INI
# 7                                Instagram                    I-N-O-I-S
# 14                                Bilibili                          o.O
# ..                                     ...                          ...
# 939                                  insta                          INI
# 949                              Instagram                        I-N-I
# 954                                    Ins                         good
# 955                                    ins                        I-N-N
# 961                                     QQ                         illi
#
#     What is your favorite game to play (either video game or IRL)?  \
# 0                                Any type of card game
# 1                                             Factorio
# 4                                           Basketball
# 7    Super Smash Bros. Ultimate (Dear Karle and Wad...
# 14                                         video games
# ..                                                 ...
# 939                                 egyptian rat screw
# 949                                             Soccer
# 954                                             Soccer
# 955                                           valorant
# 961                                     Clash of clans
#
#     What is your dream vacation location?
# 0                            The Maldives
# 1                               Mountains
# 4                              Australia
# 7                                 Nowhere
# 14                                   Alps
# ..                                    ...
# 939                              thaliand
# 949                                Norway
# 954                          Sanya, China
# 955                               finland
# 961                               Iceland
#
# [163 rows x 180 columns]

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == CHECKPOINT TEST CASES ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any errors in your output, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
assert( 'df1_treatment' in vars() ), "You do not have a DataFrame called `df1_treatment`."
assert( 'df1_control' in vars() ), "You do not have a DataFrame called `df1_control`."
assert( len(df[ df.index.isin(df1_treatment.index) & df.index.isin(df1_control.index) ]) == 0), "The `df1_treatment` and `df1_control` groups have some overlap!  There must be no overlap."
assert( len(df[ df.index.isin(df1_treatment.index) & df.index.isin(df2.index) ]) == 0), "The `df1_treatment` and `df2` groups have some overlap!  There must be no overlap."
assert( len(df[ df.index.isin(df1_control.index) & df.index.isin(df2.index) ]) == 0), "The `df1_control` and `df2` groups have some overlap!  There must be no overlap."

## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ## Part 3.3:
#
# Create a `df2_treatment` group that contains a random selection of 50% of the rows from `df2`.

# %%
df2_treatment = df2.sample(frac=0.5)
df2_treatment
# Out:
#         Name Section Does your NetID ending with odd number or even number?  \
# 815  Faizaan     Y24                      NetID ends with an odd number
# 262  Caitlyn     Y27                      NetID ends with an odd number
# 565   Andrew     Y05                     NetID ends with an even number
# 51    Carter     Y07                      NetID ends with an odd number
# 600  William     Y03                     NetID ends with an even number
# ..       ...     ...                                                ...
# 297   Senuvi     Y14                     NetID ends with an even number
# 5       Sens     Y30                     NetID ends with an even number
# 556   Sofiya     Y15                      NetID ends with an odd number
# 30    Nicole     Y01                      NetID ends with an odd number
# 802   Netsh      Y21                     NetID ends with an even number
#
#     If I flipped a coin, do you think it would it land on heads or tails?  \
# 815                                              Heads
# 262                                              Heads
# 565                                              Heads
# 51                                               Tails
# 600                                              Heads
# ..                                                 ...
# 297                                              Tails
# 5                                                Heads
# 556                                              Heads
# 30                                               Heads
# 802                                                NaN
#
#     Do you like to eat tacos or donuts?  Pick a Number: 0 or 1  \
# 815                               Tacos                    0.0
# 262                              Donuts                    1.0
# 565                              Donuts                    1.0
# 51                                Tacos                    0.0
# 600                              Donuts                    1.0
# ..                                  ...                    ...
# 297                              Donuts                    0.0
# 5                                 Tacos                    1.0
# 556                               Tacos                    1.0
# 30                                Tacos                    0.0
# 802                               Tacos                    NaN
#
#     Are you a freshman in college? Are you a morning or a night person?  \
# 815                 Not a Freshman                         Night Person
# 262            Freshman in College                       Morning Person
# 565                 Not a Freshman                       Morning Person
# 51             Freshman in College                         Night Person
# 600                 Not a Freshman                       Morning Person
# ..                             ...                                  ...
# 297                 Not a Freshman                         Night Person
# 5              Freshman in College                         Night Person
# 556            Freshman in College                       Morning Person
# 30                  Not a Freshman                         Night Person
# 802            Freshman in College                         Night Person
#
#     Are you a morning or an afternoon person?  \
# 815                          Afternoon Person
# 262                            Morning Person
# 565                            Morning Person
# 51                           Afternoon Person
# 600                            Morning Person
# ..                                        ...
# 297                            Morning Person
# 5                              Morning Person
# 556                          Afternoon Person
# 30                           Afternoon Person
# 802                                       NaN
#
#     Are you a student from Illinois or out-of-state?  ...  \
# 815                                         Illinois  ...
# 262                                     Out-of-state  ...
# 565                                         Illinois  ...
# 51                                          Illinois  ...
# 600                                     Out-of-state  ...
# ..                                               ...  ...
# 297                                     Out-of-state  ...
# 5                                           Illinois  ...
# 556                                         Illinois  ...
# 30                                          Illinois  ...
# 802                                              NaN  ...
#
#     What lab section are you enrolled in? (Use the three-letter code that starts with a "Y", like "Y42".)  \
# 815                                                Y24
# 262                                                Y27
# 565                                                Y05
# 51                                                 Y07
# 600                                                Y03
# ..                                                 ...
# 297                                                Y14
# 5                                                  Y30
# 556                                                Y15
# 30                                                 Y01
# 802                                                Y21
#
#     The level of spiciness you're comfortable with (None, mild, moderate, strong, extreme)?  \
# 815                                             strong
# 262                                              Mild
# 565                                                NaN
# 51                                                mild
# 600                                             Strong
# ..                                                 ...
# 297                                             Strong
# 5                                             Moderate
# 556                                           moderate
# 30                                                mild
# 802                                             Strong
#
#     What college is your intended major in?  (This is where you hope to end up, not necessarily your current major.)  \
# 815                                         Economics
# 262                                               Gies
# 565                                           Grainger
# 51                                                Gies
# 600                                                 CS
# ..                                                 ...
# 297                                   Computer Science
# 5                                     Grainger and LAS
# 556                                               Gies
# 30                                               media
# 802                                               Gies
#
#     What do you think is the hardest major at UIUC?  \
# 815                                     engineering
# 262                                     Engineering
# 565                                Computer Science
# 51                                      Engineering
# 600                                              CS
# ..                                              ...
# 297                           Aerospace Engineering
# 5                                               ECE
# 556                                         Pre-Med
# 30                                     engineering
# 802                                        Physics
#
#     What genre of music do you listen to? Who is your favorite music artist?  \
# 815                                   rap                              drake
# 262                                   Pop                       Taylor Swift
# 565                                  Rock                          Pearl Jam
# 51                                  Indie              Red Hot Chili Peppers
# 600                                   R&B                               Asen
# ..                                    ...                                ...
# 297                                 Indie               Cigarettes After Sex
# 5                                Shoegaze                        Fiona Apple
# 556                                   Rap                              Drake
# 30                                    pop                5 seconds of summer
# 802                                   Rnb                  Tyler the Creator
#
#     What's your favorite social media app? How do you respond to I-L-L?  \
# 815                                tik tok                        I-N-I
# 262                              Instagram                          INI
# 565                              Instagram                          INI
# 51                               Instagram                        I-N-I
# 600                                 wechat                     let's go
# ..                                     ...                          ...
# 297                              Instagram    Not sure what this means.
# 5                                  Twitter                        I-N-I
# 556                              Instagram                          INI
# 30                               instagram                          INI
# 802                               snapchat                          INI
#
#     What is your favorite game to play (either video game or IRL)?  \
# 815                                                IRL
# 262                                             Mafia
# 565                                             Tennis
# 51                                Mario Super Sluggers
# 600                                                NaN
# ..                                                 ...
# 297                                                IRL
# 5                                            Fall Guys
# 556                                        Volleyball
# 30                                 harry potter legacy
# 802                                             tennis
#
#     What is your dream vacation location?
# 815                                 dubai
# 262                             Barcelona
# 565                                Hawaii
# 51                                 Sicily
# 600                                  Amoy
# ..                                    ...
# 297                           Switzerland
# 5                                      PR
# 556                                Greece
# 30                                 greece
# 802                                 India
#
# [314 rows x 180 columns]

# %% [markdown]
# ## Part 3.4:
#
# Create a `df2_control` group that contains the other half of the rows from `df2`.

# %%
df2_control = df2[~df2.index.isin(df2_treatment.index)]
df2_control
# Out:
#                 Name Section  \
# 3           Annabel      Y05
# 8              Sarah     Y36
# 9    Pradnyan Khodke     Y24
# 10           Aaliyah     Y13
# 13            rachel     Y18
# ..               ...     ...
# 944           Mahdia     Y06
# 950           Albert     Y02
# 952             Erin     Y29
# 956          Fabian      Y11
# 964       CA Sangjun     Y23
#
#     Does your NetID ending with odd number or even number?  \
# 3                       NetID ends with an even number
# 8                        NetID ends with an odd number
# 9                        NetID ends with an odd number
# 10                      NetID ends with an even number
# 13                      NetID ends with an even number
# ..                                                 ...
# 944                     NetID ends with an even number
# 950                     NetID ends with an even number
# 952                      NetID ends with an odd number
# 956                      NetID ends with an odd number
# 964                     NetID ends with an even number
#
#     If I flipped a coin, do you think it would it land on heads or tails?  \
# 3                                                Heads
# 8                                                Heads
# 9                                                Heads
# 10                                               Heads
# 13                                               Tails
# ..                                                 ...
# 944                                              Heads
# 950                                              Tails
# 952                                              Heads
# 956                                              Tails
# 964                                              Heads
#
#     Do you like to eat tacos or donuts?  Pick a Number: 0 or 1  \
# 3                                 Tacos                    0.0
# 8                                Donuts                    0.0
# 9                                 Tacos                    1.0
# 10                               Donuts                    1.0
# 13                                Tacos                    1.0
# ..                                  ...                    ...
# 944                               Tacos                    1.0
# 950                               Tacos                    1.0
# 952                               Tacos                    1.0
# 956                               Tacos                    0.0
# 964                               Tacos                    1.0
#
#     Are you a freshman in college? Are you a morning or a night person?  \
# 3                   Not a Freshman                         Night Person
# 8              Freshman in College                       Morning Person
# 9                   Not a Freshman                       Morning Person
# 10             Freshman in College                         Night Person
# 13             Freshman in College                         Night Person
# ..                             ...                                  ...
# 944                 Not a Freshman                         Night Person
# 950            Freshman in College                         Night Person
# 952            Freshman in College                       Morning Person
# 956                 Not a Freshman                         Night Person
# 964                 Not a Freshman                         Night Person
#
#     Are you a morning or an afternoon person?  \
# 3                            Afternoon Person
# 8                              Morning Person
# 9                              Morning Person
# 10                           Afternoon Person
# 13                             Morning Person
# ..                                        ...
# 944                          Afternoon Person
# 950                          Afternoon Person
# 952                          Afternoon Person
# 956                          Afternoon Person
# 964                            Morning Person
#
#     Are you a student from Illinois or out-of-state?  ...  \
# 3                                           Illinois  ...
# 8                                           Illinois  ...
# 9                                           Illinois  ...
# 10                                          Illinois  ...
# 13                                          Illinois  ...
# ..                                               ...  ...
# 944                                         Illinois  ...
# 950                                         Illinois  ...
# 952                                         Illinois  ...
# 956                                         Illinois  ...
# 964                                     Out-of-state  ...
#
#     What lab section are you enrolled in? (Use the three-letter code that starts with a "Y", like "Y42".)  \
# 3                                                  Y05
# 8                                                  Y36
# 9                                                  Y24
# 10                                                 Y13
# 13                                                 Y18
# ..                                                 ...
# 944                                                Y06
# 950                                                Y02
# 952                                                Y29
# 956                                                Y11
# 964                                                Y23
#
#     The level of spiciness you're comfortable with (None, mild, moderate, strong, extreme)?  \
# 3                                             Moderate
# 8                                               Strong
# 9                                               Strong
# 10                                             Extreme
# 13                                              strong
# ..                                                 ...
# 944                                           moderate
# 950                                             strong
# 952                                             strong
# 956                                           Extreme
# 964                                               Mild
#
#     What college is your intended major in?  (This is where you hope to end up, not necessarily your current major.)  \
# 3                                     ISchool and LAS
# 8                                              iSchool
# 9                                                  LAS
# 10                                             iSchool
# 13                                           grainger
# ..                                                 ...
# 944                               Information sciences
# 950                                                DgS
# 952                                               UIUC
# 956                                                 IS
# 964                                         Statistics
#
#     What do you think is the hardest major at UIUC?  \
# 3                                 Computer science
# 8                                  Computer Science
# 9                                               ECE
# 10                                 Computer Science
# 13                         biochemical engineering
# ..                                              ...
# 944                                computer science
# 950                                       Chemistry
# 952                                              CS
# 956                               Computer science
# 964                                     Engineering
#
#     What genre of music do you listen to? Who is your favorite music artist?  \
# 3                              Rap or r&b                            Eminem
# 8                                   Indie                       Taylor Swift
# 9              Hip hop, R&B, Indie, Rock,                  Tyler The Creator
# 10                                    Pop                       Taylor Swift
# 13                                    pop                           newjeans
# ..                                    ...                                ...
# 944                                 indie                       taylor swift
# 950                                   rap                        purity ring
# 952          R&B, Indie music, pop, K-pop                       Shawn Mendes
# 956                                   Rap                              Drake
# 964                                   RnB                      Wave to Earth
#
#     What's your favorite social media app? How do you respond to I-L-L?  \
# 3                                Snapchat                           INI
# 8                                Instagram                        I-N-I
# 9                                        X                        I-N-I
# 10                                  TikTok                          INI
# 13                              instagram                         I-N-I
# ..                                     ...                          ...
# 944                              instagram                          INI
# 950                              INStagram                          INI
# 952                              instagram                        I-N-I
# 956                                      X                        I-N-I
# 964                              Instagram                          INI
#
#     What is your favorite game to play (either video game or IRL)?  \
# 3                             Volleyball or fortnight
# 8                                                  Uno
# 9                                           Basketball
# 10                                    Capture the Flag
# 13                                              euchre
# ..                                                 ...
# 944                                          beer pong
# 950                                              Chess
# 952                                                IRL
# 956                                          Valorant
# 964                                     Clash of Clans
#
#     What is your dream vacation location?
# 3                                 Greece
# 8                                  Taiwan
# 9                                    Asia
# 10                                  Spain
# 13                                 hawaii
# ..                                    ...
# 944                                  cabo
# 950                            California
# 952                              New York
# 956                                Greece
# 964                                 Korea
#
# [315 rows x 180 columns]

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == CHECKPOINT TEST CASES ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any errors in your output, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
assert( 'df2_treatment' in vars() ), "You do not have a DataFrame called `df2_treatment`."
assert( 'df2_control' in vars() ), "You do not have a DataFrame called `df2_control`."
assert( len(df[ df.index.isin(df2_treatment.index) & df.index.isin(df2_control.index) ]) == 0), "The `df2_treatment` and `df2_control` groups have some overlap!  There must be no overlap."
assert( len(df[ df.index.isin(df2_treatment.index) & df.index.isin(df1.index) ]) == 0), "The `df2_treatment` and `df1` groups have some overlap!  There must be no overlap."
assert( len(df[ df.index.isin(df2_control.index) & df.index.isin(df1.index) ]) == 0), "The `df2_control` and `df1` groups have some overlap!  There must be no overlap."


## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ## Part 3.5:
#
# Finally, read the guide: **Combining DataFrames by Concatenation** (https://discovery.cs.illinois.edu/guides/Combining-DataFrames/Combining-DataFrames-by-Concatenation/) to learn how to combine `df1_treatment` and `df2_treatment` together into one group called `treatment`.
#
# FYI, you will not need to reset the index here!

# %%
treatment = pd.concat([df1_treatment, df2_treatment], axis=1)
treatment
# Out:
#          Name Section Does your NetID ending with odd number or even number?  \
# 599  Jeongyun     Y04                      NetID ends with an odd number
# 253   Victor      Y26                     NetID ends with an even number
# 941   Michael     Y29                     NetID ends with an even number
# 354    Landon     Y12                     NetID ends with an even number
# 830  CA Salar     Y26                     NetID ends with an even number
# ..        ...     ...                                                ...
# 297       NaN     NaN                                                NaN
# 5         NaN     NaN                                                NaN
# 556       NaN     NaN                                                NaN
# 30        NaN     NaN                                                NaN
# 802       NaN     NaN                                                NaN
#
#     If I flipped a coin, do you think it would it land on heads or tails?  \
# 599                                              Heads
# 253                                              Tails
# 941                                              Heads
# 354                                              Tails
# 830                                              Heads
# ..                                                 ...
# 297                                                NaN
# 5                                                  NaN
# 556                                                NaN
# 30                                                 NaN
# 802                                                NaN
#
#     Do you like to eat tacos or donuts?  Pick a Number: 0 or 1  \
# 599                               Tacos                    0.0
# 253                               Tacos                    1.0
# 941                              Donuts                    1.0
# 354                              Donuts                    1.0
# 830                               Tacos                    0.0
# ..                                  ...                    ...
# 297                                 NaN                    NaN
# 5                                   NaN                    NaN
# 556                                 NaN                    NaN
# 30                                  NaN                    NaN
# 802                                 NaN                    NaN
#
#     Are you a freshman in college? Are you a morning or a night person?  \
# 599                 Not a Freshman                       Morning Person
# 253            Freshman in College                         Night Person
# 941            Freshman in College                         Night Person
# 354            Freshman in College                         Night Person
# 830                 Not a Freshman                         Night Person
# ..                             ...                                  ...
# 297                            NaN                                  NaN
# 5                              NaN                                  NaN
# 556                            NaN                                  NaN
# 30                             NaN                                  NaN
# 802                            NaN                                  NaN
#
#     Are you a morning or an afternoon person?  \
# 599                          Afternoon Person
# 253                          Afternoon Person
# 941                          Afternoon Person
# 354                          Afternoon Person
# 830                          Afternoon Person
# ..                                        ...
# 297                                       NaN
# 5                                         NaN
# 556                                       NaN
# 30                                        NaN
# 802                                       NaN
#
#     Are you a student from Illinois or out-of-state?  ...  \
# 599                                     Out-of-state  ...
# 253                                         Illinois  ...
# 941                                     Out-of-state  ...
# 354                                         Illinois  ...
# 830                                     Out-of-state  ...
# ..                                               ...  ...
# 297                                              NaN  ...
# 5                                                NaN  ...
# 556                                              NaN  ...
# 30                                               NaN  ...
# 802                                              NaN  ...
#
#     What lab section are you enrolled in? (Use the three-letter code that starts with a "Y", like "Y42".)  \
# 599                                                NaN
# 253                                                NaN
# 941                                                NaN
# 354                                                NaN
# 830                                                NaN
# ..                                                 ...
# 297                                                Y14
# 5                                                  Y30
# 556                                                Y15
# 30                                                 Y01
# 802                                                Y21
#
#     The level of spiciness you're comfortable with (None, mild, moderate, strong, extreme)?  \
# 599                                                NaN
# 253                                                NaN
# 941                                                NaN
# 354                                                NaN
# 830                                                NaN
# ..                                                 ...
# 297                                             Strong
# 5                                             Moderate
# 556                                           moderate
# 30                                                mild
# 802                                             Strong
#
#     What college is your intended major in?  (This is where you hope to end up, not necessarily your current major.)  \
# 599                                                NaN
# 253                                                NaN
# 941                                                NaN
# 354                                                NaN
# 830                                                NaN
# ..                                                 ...
# 297                                   Computer Science
# 5                                     Grainger and LAS
# 556                                               Gies
# 30                                               media
# 802                                               Gies
#
#     What do you think is the hardest major at UIUC?  \
# 599                                             NaN
# 253                                             NaN
# 941                                             NaN
# 354                                             NaN
# 830                                             NaN
# ..                                              ...
# 297                           Aerospace Engineering
# 5                                               ECE
# 556                                         Pre-Med
# 30                                     engineering
# 802                                        Physics
#
#     What genre of music do you listen to? Who is your favorite music artist?  \
# 599                                   NaN                                NaN
# 253                                   NaN                                NaN
# 941                                   NaN                                NaN
# 354                                   NaN                                NaN
# 830                                   NaN                                NaN
# ..                                    ...                                ...
# 297                                 Indie               Cigarettes After Sex
# 5                                Shoegaze                        Fiona Apple
# 556                                   Rap                              Drake
# 30                                    pop                5 seconds of summer
# 802                                   Rnb                  Tyler the Creator
#
#     What's your favorite social media app? How do you respond to I-L-L?  \
# 599                                    NaN                          NaN
# 253                                    NaN                          NaN
# 941                                    NaN                          NaN
# 354                                    NaN                          NaN
# 830                                    NaN                          NaN
# ..                                     ...                          ...
# 297                              Instagram    Not sure what this means.
# 5                                  Twitter                        I-N-I
# 556                              Instagram                          INI
# 30                               instagram                          INI
# 802                               snapchat                          INI
#
#     What is your favorite game to play (either video game or IRL)?  \
# 599                                                NaN
# 253                                                NaN
# 941                                                NaN
# 354                                                NaN
# 830                                                NaN
# ..                                                 ...
# 297                                                IRL
# 5                                            Fall Guys
# 556                                        Volleyball
# 30                                 harry potter legacy
# 802                                             tennis
#
#     What is your dream vacation location?
# 599                                   NaN
# 253                                   NaN
# 941                                   NaN
# 354                                   NaN
# 830                                   NaN
# ..                                    ...
# 297                           Switzerland
# 5                                      PR
# 556                                Greece
# 30                                 greece
# 802                                 India
#
# [478 rows x 360 columns]

# %% [markdown]
# ## Part 3.6:
#
# Using the same technique, combine `df1_control` and `df2_control` together into one group called `control`:

# %%
control = pd.concat([df1_control, df2_control], axis=1)
control
# Out:
#             Name Section  \
# 0    Prof. Karle  L1, L2
# 1     Prof. Wade  L1, L2
# 4         Ayden      Y14
# 7     Joseph Kim     Y16
# 14        George     Y32
# ..           ...     ...
# 944          NaN     NaN
# 950          NaN     NaN
# 952          NaN     NaN
# 956          NaN     NaN
# 964          NaN     NaN
#
#     Does your NetID ending with odd number or even number?  \
# 0                        NetID ends with an odd number
# 1                                                  NaN
# 4                       NetID ends with an even number
# 7                       NetID ends with an even number
# 14                      NetID ends with an even number
# ..                                                 ...
# 944                                                NaN
# 950                                                NaN
# 952                                                NaN
# 956                                                NaN
# 964                                                NaN
#
#     If I flipped a coin, do you think it would it land on heads or tails?  \
# 0                                                Heads
# 1                                                Heads
# 4                                                Heads
# 7                                                Heads
# 14                                               Heads
# ..                                                 ...
# 944                                                NaN
# 950                                                NaN
# 952                                                NaN
# 956                                                NaN
# 964                                                NaN
#
#     Do you like to eat tacos or donuts?  Pick a Number: 0 or 1  \
# 0                                 Tacos                    0.0
# 1                                 Tacos                    1.0
# 4                                Donuts                    1.0
# 7                                Donuts                    1.0
# 14                               Donuts                    1.0
# ..                                  ...                    ...
# 944                                 NaN                    NaN
# 950                                 NaN                    NaN
# 952                                 NaN                    NaN
# 956                                 NaN                    NaN
# 964                                 NaN                    NaN
#
#     Are you a freshman in college? Are you a morning or a night person?  \
# 0                   Not a Freshman                         Night Person
# 1                   Not a Freshman                         Night Person
# 4              Freshman in College                         Night Person
# 7                   Not a Freshman                         Night Person
# 14             Freshman in College                         Night Person
# ..                             ...                                  ...
# 944                            NaN                                  NaN
# 950                            NaN                                  NaN
# 952                            NaN                                  NaN
# 956                            NaN                                  NaN
# 964                            NaN                                  NaN
#
#     Are you a morning or an afternoon person?  \
# 0                            Afternoon Person
# 1                            Afternoon Person
# 4                              Morning Person
# 7                            Afternoon Person
# 14                           Afternoon Person
# ..                                        ...
# 944                                       NaN
# 950                                       NaN
# 952                                       NaN
# 956                                       NaN
# 964                                       NaN
#
#     Are you a student from Illinois or out-of-state?  ...  \
# 0                                           Illinois  ...
# 1                                                NaN  ...
# 4                                           Illinois  ...
# 7                                           Illinois  ...
# 14                                      Out-of-state  ...
# ..                                               ...  ...
# 944                                              NaN  ...
# 950                                              NaN  ...
# 952                                              NaN  ...
# 956                                              NaN  ...
# 964                                              NaN  ...
#
#     What lab section are you enrolled in? (Use the three-letter code that starts with a "Y", like "Y42".)  \
# 0                                                  NaN
# 1                                                  NaN
# 4                                                  NaN
# 7                                                  NaN
# 14                                                 NaN
# ..                                                 ...
# 944                                                Y06
# 950                                                Y02
# 952                                                Y29
# 956                                                Y11
# 964                                                Y23
#
#     The level of spiciness you're comfortable with (None, mild, moderate, strong, extreme)?  \
# 0                                                  NaN
# 1                                                  NaN
# 4                                                  NaN
# 7                                                  NaN
# 14                                                 NaN
# ..                                                 ...
# 944                                           moderate
# 950                                             strong
# 952                                             strong
# 956                                           Extreme
# 964                                               Mild
#
#     What college is your intended major in?  (This is where you hope to end up, not necessarily your current major.)  \
# 0                                                  NaN
# 1                                                  NaN
# 4                                                  NaN
# 7                                                  NaN
# 14                                                 NaN
# ..                                                 ...
# 944                               Information sciences
# 950                                                DgS
# 952                                               UIUC
# 956                                                 IS
# 964                                         Statistics
#
#     What do you think is the hardest major at UIUC?  \
# 0                                               NaN
# 1                                               NaN
# 4                                               NaN
# 7                                               NaN
# 14                                              NaN
# ..                                              ...
# 944                                computer science
# 950                                       Chemistry
# 952                                              CS
# 956                               Computer science
# 964                                     Engineering
#
#     What genre of music do you listen to? Who is your favorite music artist?  \
# 0                                     NaN                                NaN
# 1                                     NaN                                NaN
# 4                                     NaN                                NaN
# 7                                     NaN                                NaN
# 14                                    NaN                                NaN
# ..                                    ...                                ...
# 944                                 indie                       taylor swift
# 950                                   rap                        purity ring
# 952          R&B, Indie music, pop, K-pop                       Shawn Mendes
# 956                                   Rap                              Drake
# 964                                   RnB                      Wave to Earth
#
#     What's your favorite social media app? How do you respond to I-L-L?  \
# 0                                      NaN                          NaN
# 1                                      NaN                          NaN
# 4                                      NaN                          NaN
# 7                                      NaN                          NaN
# 14                                     NaN                          NaN
# ..                                     ...                          ...
# 944                              instagram                          INI
# 950                              INStagram                          INI
# 952                              instagram                        I-N-I
# 956                                      X                        I-N-I
# 964                              Instagram                          INI
#
#     What is your favorite game to play (either video game or IRL)?  \
# 0                                                  NaN
# 1                                                  NaN
# 4                                                  NaN
# 7                                                  NaN
# 14                                                 NaN
# ..                                                 ...
# 944                                          beer pong
# 950                                              Chess
# 952                                                IRL
# 956                                          Valorant
# 964                                     Clash of Clans
#
#     What is your dream vacation location?
# 0                                     NaN
# 1                                     NaN
# 4                                     NaN
# 7                                     NaN
# 14                                    NaN
# ..                                    ...
# 944                                  cabo
# 950                            California
# 952                              New York
# 956                                Greece
# 964                                 Korea
#
# [478 rows x 360 columns]

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == CHECKPOINT TEST CASES ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any errors in your output, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
assert( len(df[ df.index.isin(treatment.index) & df.index.isin(control.index) ]) == 0), "The `treatment` and `control` groups have some overlap!  There must be no overlap."

## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ## Analysis: Blocking

# %% [markdown]
# **Q: In your own words, explain what blocking is and why it is useful to someone who has never taken a statistics course before! You can use what you did above as an example in your explanation if you'd like. Make sure to include what blocking is and why it is useful. Write at least three complete sentences to answer this question.**

# %% [markdown]
# Blocking is separating your overall sample into two different groups, for example one group with a high GPA and another with lower GPA. Then half of each group is put into the treatment and control groups. This ensures that both the treatment and control groups are as alike as possible--they both have the same amount of students with high GPAs and low GPAs. This means that GPA will not be a confounding variable.

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# # Submission
#
# You're almost done!  All you need to do is to commit your lab to GitHub:
#
# 1.  ⚠️ **Make certain to save your work.** ⚠️ To do this, go to **File => Save All**
#
# 2.  After you have saved, exit this notebook and follow the Canvas instructions to commit this lab to your Git repository!
#
# 3. Your TA will grade your submission and provide you feedback after the lab is due. :)
